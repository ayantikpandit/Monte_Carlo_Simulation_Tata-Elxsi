# %%
# %pip install --upgrade plotly pandas
# Out:
# Requirement already satisfied: plotly in ./.venv-1/lib/python3.13/site-packages (7.1.0)
# Requirement already satisfied: pandas in ./.venv-1/lib/python3.13/site-packages (3.0.6)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv-1/lib/python3.13/site-packages (from plotly) (2.26.0)
# Requirement already satisfied: packaging in ./.venv-1/lib/python3.13/site-packages (from plotly) (26.3)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv-1/lib/python3.13/site-packages (from pandas) (2.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv-1/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv-1/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import datetime as dt 
import yfinance as yf 
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import random as rd
import plotly.graph_objects as go

# %%
raw_df = pd.read_csv('Diversified_stocks.csv')
raw_df
# Out:
#             Date  Tata Elxsi     HDFC  Sun Pharma        LT    NTPC       HAL  \
# 0     2021-01-01    1751.431  663.906     561.122  1218.873   79.22   388.796
# 1     2021-01-04    1763.760  659.689     568.792  1235.413   79.22   402.455
# 2     2021-01-05    1835.770  664.674     567.898  1227.613   78.06   418.178
# 3     2021-01-06    1870.180  661.809     569.639  1234.849   78.26   428.274
# 4     2021-01-07    1874.259  659.806     566.439  1258.296   77.58   422.239
# ...          ...         ...      ...         ...       ...     ...       ...
# 1412  2026-09-14    3383.000  708.250    1840.000  3930.700  333.40  4905.000
# 1413  2026-09-15    3440.000  716.550    1835.000  3850.700  329.50  4695.000
# 1414  2026-09-16    3373.000  721.500    1853.500  3807.700  327.00  4695.600
# 1415  2026-09-17    3381.800  713.000    1867.300  3836.200  329.60  4788.000
# 1416  2026-09-18    3266.700  731.000    1837.300  3885.000  323.65  4800.300
#
#          Titan    Airtel     Maruti
# 0     1529.710   488.066   7298.333
# 1     1522.153   489.913   7308.772
# 2     1541.831   486.976   7264.316
# 3     1543.451   497.682   7238.838
# 4     1513.761   516.583   7179.483
# ...        ...       ...        ...
# 1412  5009.500  1831.100  12400.000
# 1413  4856.000  1830.400  12231.000
# 1414  4908.500  1835.000  12166.000
# 1415  4841.000  1836.000  12338.000
# 1416  4798.500  1893.300  12103.000
#
# [1417 rows x 10 columns]

# %%
portfolio_df = raw_df.copy()
scaled_df = price_scaling(portfolio_df)
scaled_df
# Out:
#             Date  Tata Elxsi      HDFC  Sun Pharma        LT      NTPC  \
# 0     2021-01-01    1.000000  1.000000    1.000000  1.000000  1.000000
# 1     2021-01-04    1.007039  0.993648    1.013669  1.013570  1.000000
# 2     2021-01-05    1.048154  1.001157    1.012076  1.007171  0.985357
# 3     2021-01-06    1.067801  0.996841    1.015179  1.013107  0.987882
# 4     2021-01-07    1.070130  0.993824    1.009476  1.032344  0.979298
# ...          ...         ...       ...         ...       ...       ...
# 1412  2026-09-14    1.931563  1.066793    3.279144  3.224864  4.208533
# 1413  2026-09-15    1.964108  1.079294    3.270234  3.159230  4.159303
# 1414  2026-09-16    1.925854  1.086750    3.303203  3.123951  4.127746
# 1415  2026-09-17    1.930878  1.073947    3.327797  3.147334  4.160566
# 1416  2026-09-18    1.865161  1.101059    3.274332  3.187371  4.085458
#
#             HAL     Titan    Airtel    Maruti
# 0      1.000000  1.000000  1.000000  1.000000
# 1      1.035132  0.995060  1.003784  1.001430
# 2      1.075572  1.007924  0.997767  0.995339
# 3      1.101539  1.008983  1.019702  0.991848
# 4      1.086017  0.989574  1.058429  0.983715
# ...         ...       ...       ...       ...
# 1412  12.615871  3.274804  3.751747  1.699018
# 1413  12.075742  3.174458  3.750312  1.675862
# 1414  12.077285  3.208778  3.759737  1.666956
# 1415  12.314942  3.164652  3.761786  1.690523
# 1416  12.346578  3.136869  3.879188  1.658324
#
# [1417 rows x 10 columns]

# %%
def price_scaling(raw_prices_df):
    scaled_prices_df = raw_prices_df.copy()
    for i in raw_prices_df.columns[1:]:
          scaled_prices_df[i] = raw_prices_df[i]/raw_prices_df[i][0]
    return scaled_prices_df

# %%
scaled_df = price_scaling(raw_df)
scaled_df
# Out:
#             Date  Tata Elxsi      HDFC  Sun Pharma        LT      NTPC  \
# 0     2021-01-01    1.000000  1.000000    1.000000  1.000000  1.000000
# 1     2021-01-04    1.007039  0.993648    1.013669  1.013570  1.000000
# 2     2021-01-05    1.048154  1.001157    1.012076  1.007171  0.985357
# 3     2021-01-06    1.067801  0.996841    1.015179  1.013107  0.987882
# 4     2021-01-07    1.070130  0.993824    1.009476  1.032344  0.979298
# ...          ...         ...       ...         ...       ...       ...
# 1412  2026-09-14    1.931563  1.066793    3.279144  3.224864  4.208533
# 1413  2026-09-15    1.964108  1.079294    3.270234  3.159230  4.159303
# 1414  2026-09-16    1.925854  1.086750    3.303203  3.123951  4.127746
# 1415  2026-09-17    1.930878  1.073947    3.327797  3.147334  4.160566
# 1416  2026-09-18    1.865161  1.101059    3.274332  3.187371  4.085458
#
#             HAL     Titan    Airtel    Maruti
# 0      1.000000  1.000000  1.000000  1.000000
# 1      1.035132  0.995060  1.003784  1.001430
# 2      1.075572  1.007924  0.997767  0.995339
# 3      1.101539  1.008983  1.019702  0.991848
# 4      1.086017  0.989574  1.058429  0.983715
# ...         ...       ...       ...       ...
# 1412  12.615871  3.274804  3.751747  1.699018
# 1413  12.075742  3.174458  3.750312  1.675862
# 1414  12.077285  3.208778  3.759737  1.666956
# 1415  12.314942  3.164652  3.761786  1.690523
# 1416  12.346578  3.136869  3.879188  1.658324
#
# [1417 rows x 10 columns]

# %%
weights = [0.032266, 0.094461, 0.117917, 0.132624, 0.145942, 0.128299, 0.10009, 0.007403, 0.088581, 0.152417]
weights
# Out:
# [0.032266,
#  0.094461,
#  0.117917,
#  0.132624,
#  0.145942,
#  0.128299,
#  0.10009,
#  0.007403,
#  0.088581,
#  0.152417]

# %%
def generate_portfolio_weights(n):
    weights = []
    for i in range(n):
        weights.append(rd.random())
        
    weights = weights/np.sum(weights)
    return weights

# %%
weights = generate_portfolio_weights(6)
print(weights)
# Out:
# [0.07495886 0.03724818 0.24743493 0.26412189 0.08882096 0.28741518]

# %%
def asset_allocation(df, weights, initial_investment):
    portfolio_df = df.copy()
    scaled_df = price_scaling(df)
  
    for i, stock in enumerate(scaled_df.columns[1:]):
        portfolio_df[stock] = scaled_df[stock] * weights[i] * initial_investment
    portfolio_df['Portfolio Value [INR]'] = portfolio_df[portfolio_df != 'Date'].sum(axis = 1, numeric_only = True)
    portfolio_df['Portfolio Daily Return [%]'] = portfolio_df['Portfolio Value [INR]'].pct_change(1) * 100 
    portfolio_df.replace(np.nan, 0, inplace = True)
    
    return portfolio_df

# %%
n = len(raw_df.columns)-1

print('Number of stocks in the portfolio = {}'.format(n))
weights = generate_portfolio_weights(n).round(6)
print('Portfolio weights in order = {}'.format(weights))
portfolio_df = asset_allocation(raw_df, weights, 1000000)
portfolio_df.round(1)
# Out:
# Number of stocks in the portfolio = 9
# Portfolio weights in order = [0.13721  0.142512 0.092397 0.080761 0.152854 0.005906 0.140269 0.154496
#  0.093596]
#             Date  Tata Elxsi      HDFC  Sun Pharma        LT      NTPC  \
# 0     2021-01-01    137210.0  142512.0     92397.0   80761.0  152854.0
# 1     2021-01-04    138175.9  141606.8     93660.0   81856.9  152854.0
# 2     2021-01-05    143817.3  142676.9     93512.8   81340.1  150615.8
# 3     2021-01-06    146513.0  142061.9     93799.4   81819.5  151001.7
# 4     2021-01-07    146832.5  141631.9     93272.5   83373.1  149689.6
# ...          ...         ...       ...         ...       ...       ...
# 1412  2026-09-14    265029.8  152030.7    302983.1  260443.3  643291.1
# 1413  2026-09-15    269495.3  153812.4    302159.8  255142.6  635766.1
# 1414  2026-09-16    264246.4  154874.9    305206.1  252293.4  630942.4
# 1415  2026-09-17    264935.8  153050.4    307478.4  254181.8  635959.1
# 1416  2026-09-18    255918.7  156914.2    302538.5  257415.2  624478.6
#
#           HAL     Titan    Airtel    Maruti  Portfolio Value [INR]  \
# 0      5906.0  140269.0  154496.0   93596.0              1000001.0
# 1      6113.5  139576.0  155080.7   93729.9              1002653.6
# 2      6352.3  141380.5  154151.0   93159.8              1007006.3
# 3      6505.7  141529.0  157539.9   92833.0              1013603.2
# 4      6414.0  138806.5  163523.0   92071.8              1015615.1
# ...       ...       ...       ...       ...                    ...
# 1412  74509.3  459353.4  579629.9  159021.3              2896292.0
# 1413  71319.3  445278.0  579408.3  156854.0              2869235.8
# 1414  71328.4  450092.1  580864.4  156020.4              2865868.6
# 1415  72732.0  443902.6  581180.9  158226.2              2871647.3
# 1416  72918.9  440005.5  599319.1  155212.5              2864721.2
#
#       Portfolio Daily Return [%]
# 0                            0.0
# 1                            0.3
# 2                            0.4
# 3                            0.7
# 4                            0.2
# ...                          ...
# 1412                         0.0
# 1413                        -0.9
# 1414                        -0.1
# 1415                         0.2
# 1416                        -0.2
#
# [1417 rows x 12 columns]

# %%
# %pip uninstall plotly -y
# %pip install plotly --no-cache-dir
# Out:
# Found existing installation: plotly 7.1.0
# Uninstalling plotly-7.1.0:
#   Successfully uninstalled plotly-7.1.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting plotly
#   Downloading plotly-7.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv-1/lib/python3.13/site-packages (from plotly) (2.26.0)
# Requirement already satisfied: packaging in ./.venv-1/lib/python3.13/site-packages (from plotly) (26.3)
# Downloading plotly-7.1.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 6.5 MB/s  0:00:01 eta 0:00:01m
# Installing collected packages: plotly
# Successfully installed plotly-7.1.0
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly

import plotly.express as px

# %%
def plot_financial_data(df, title):
    
    fig = px.line(title = title)
    
    # For loop that plots all stock prices in the pandas dataframe df
    # Note that index starts with 1 because we want to skip the date column
    
    for i in df.columns[1:]:
        fig.add_scatter(x = df['Date'], y = df[i], name = i)

    fig.show()

# %%
portfolio_df
# Out:
#             Date     Tata Elxsi           HDFC     Sun Pharma             LT  \
# 0     2021-01-01  137210.000000  142512.000000   92397.000000   80761.000000
# 1     2021-01-04  138175.874242  141606.791877   93659.978443   81856.919706
# 2     2021-01-05  143817.256689  142676.856495   93512.768179   81340.101465
# 3     2021-01-06  146512.992975  142061.864493   93799.449466   81819.549772
# 4     2021-01-07  146832.548579  141631.906734   93272.522345   83373.118656
# ...          ...            ...            ...            ...            ...
# 1412  2026-09-14  265029.812765  152030.745316  302983.094585  260443.264146
# 1413  2026-09-15  269495.286997  153812.397538  302159.770959  255142.564238
# 1414  2026-09-16  264246.396233  154874.949164  305206.068377  252293.438037
# 1415  2026-09-17  264935.802781  153050.365564  307478.441587  254181.812379
# 1416  2026-09-18  255918.678498  156914.189659  302538.499827  257415.239324
#
#                NTPC           HAL          Titan         Airtel  \
# 0     152854.000000   5906.000000  140269.000000  154496.000000
# 1     152854.000000   6113.486841  139576.049811  155080.662960
# 2     150615.794496   6352.326845  141380.452856  154150.963386
# 3     151001.691997   6505.689987  141529.001130  157539.919339
# 4     149689.640495   6414.015407  138806.533074  163522.980843
# ...             ...           ...            ...            ...
# 1412  643291.133552  74509.331372  459353.443136  579629.856618
# 1413  635766.132290  71319.329417  445278.035706  579408.273471
# 1414  630942.413532  71328.443708  450092.100137  580864.391291
# 1415  635959.081040  72732.044568  443902.588726  581180.938644
# 1416  624478.630396  72918.887540  440005.488949  599319.101925
#
#              Maruti  Portfolio Value [INR]  Portfolio Daily Return [%]
# 0      93596.000000           1.000001e+06                    0.000000
# 1      93729.872851           1.002654e+06                    0.265263
# 2      93159.755842           1.007006e+06                    0.434112
# 3      92833.018368           1.013603e+06                    0.655100
# 4      92071.832139           1.015615e+06                    0.198492
# ...             ...                    ...                         ...
# 1412  159021.299795           2.896292e+06                    0.000000
# 1413  156853.993371           2.869236e+06                   -0.934167
# 1414  156020.413977           2.865869e+06                   -0.117354
# 1415  158226.193296           2.871647e+06                    0.201637
# 1416  155212.483179           2.864721e+06                   -0.241188
#
# [1417 rows x 12 columns]

# %%
plot_financial_data(portfolio_df[['Date', 'Portfolio Daily Return [%]']], 'Portfolio Percentage Daily Return [%]')

plot_financial_data(portfolio_df.drop(['Portfolio Value [INR]', 'Portfolio Daily Return [%]'], axis = 1), 'Portfolio positions [$]')

plot_financial_data(portfolio_df[['Date', 'Portfolio Value [INR]']], 'Total Portfolio Value [$]')

# %%
def simulation_engine(weights, initial_investment):
    
    portfolio_df = asset_allocation(
        raw_df,
        weights,
        initial_investment
    )
    
    return_on_investment = (
        (portfolio_df['Portfolio Value [INR]'].iloc[-1] -
         portfolio_df['Portfolio Value [INR]'].iloc[0])
        / portfolio_df['Portfolio Value [INR]'].iloc[0]
    ) * 100
    
    # Remove non-stock columns
    portfolio_daily_return_df = portfolio_df.drop(
        columns=[
            'Date',
            'Portfolio Value [INR]',
            'Portfolio Daily Return [%]'
        ]
    )
    
    # Calculate daily returns of individual stocks
    portfolio_daily_return_df = portfolio_daily_return_df.pct_change(1)
    
    # Expected annual portfolio return
    expected_portfolio_return = (
        np.sum(
            weights * portfolio_daily_return_df.mean()
        ) * 252
    )
    
    # Annualized covariance matrix
    covariance = portfolio_daily_return_df.cov() * 252
    
    # Portfolio volatility
    expected_volatility = np.sqrt(
        np.dot(
            weights.T,
            np.dot(covariance, weights)
        )
    )
    
    # Risk-free rate assumption
    rf = 0.07
    
    # Sharpe ratio
    sharpe_ratio = (
        expected_portfolio_return - rf
    ) / expected_volatility
    
    return (
        expected_portfolio_return,
        expected_volatility,
        sharpe_ratio,
        portfolio_df['Portfolio Value [INR]'].iloc[-1],
        return_on_investment
    )

# %%
initial_investment = 1000000
portfolio_metrics = simulation_engine(weights, initial_investment)

# %%
print('Expected Portfolio Annual Return = {:.2f}%'.format(portfolio_metrics[0] * 100))
print('Portfolio Standard Deviation (Volatility) = {:.2f}%'.format(portfolio_metrics[1] * 100))
print('Sharpe Ratio = {:.2f}'.format(portfolio_metrics[2]))
print('Portfolio Final Value = ${:.2f}'.format(portfolio_metrics[3]))
print('Return on Investment = {:.2f}%'.format(portfolio_metrics[4]))
# Out:
# Expected Portfolio Annual Return = 24.76%
# Portfolio Standard Deviation (Volatility) = 15.90%
# Sharpe Ratio = 1.12
# Portfolio Final Value = $4324642.08
# Return on Investment = 332.46%

# %%
#MONTE CARLO SIMULATION function for 5000 runs
sim_runs = 5000
initial_investment = 1000000

# Placeholder to store all weights
weights_runs = np.zeros((sim_runs, n))

# Placeholder to store all Sharpe ratios
sharpe_ratio_runs = np.zeros(sim_runs)

# Placeholder to store all expected returns
expected_portfolio_returns_runs = np.zeros(sim_runs)

# Placeholder to store all volatility values
volatility_runs = np.zeros(sim_runs)

# Placeholder to store all returns on investment
return_on_investment_runs = np.zeros(sim_runs)

# Placeholder to store all final portfolio values
final_value_runs = np.zeros(sim_runs)

for i in range(sim_runs):
    # Generate random weights 
    weights = generate_portfolio_weights(n)
    # Store the weights
    weights_runs[i,:] = weights
    
    # Call "simulation_engine" function and store Sharpe ratio, return and volatility
    # Note that asset allocation is performed using the "asset_allocation" function  
    expected_portfolio_returns_runs[i], volatility_runs[i], sharpe_ratio_runs[i], final_value_runs[i], return_on_investment_runs[i] = simulation_engine(weights, initial_investment)
    print("Simulation Run = {}".format(i))   
    print("Weights = {}, Final Value = ${:.2f}, Sharpe Ratio = {:.2f}".format(weights_runs[i].round(3), final_value_runs[i], sharpe_ratio_runs[i]))   
    print('\n')
# Out:
# Simulation Run = 0
# Weights = [0.079 0.167 0.196 0.029 0.223 0.143 0.125 0.018 0.019], Final Value = $4239553.76, Sharpe Ratio = 1.14
#
#
# Simulation Run = 1
# Weights = [0.141 0.058 0.149 0.123 0.111 0.07  0.114 0.147 0.088], Final Value = $3591966.42, Sharpe Ratio = 1.09
#
#
# Simulation Run = 2
# Weights = [0.108 0.194 0.033 0.114 0.186 0.031 0.135 0.077 0.122], Final Value = $2953709.94, Sharpe Ratio = 0.83
#
#
# Simulation Run = 3
# Weights = [0.104 0.082 0.177 0.06  0.182 0.044 0.138 0.032 0.18 ], Final Value = $3200172.93, Sharpe Ratio = 0.96
#
#
# Simulation Run = 4
# Weights = [0.076 0.073 0.023 0.072 0.105 0.187 0.124 0.158 0.182], Final Value = $4566423.25, Sharpe Ratio = 1.17
#
#
# Simulation Run = 5
# Weights = [0.182 0.111 0.108 0.056 0.111 0.123 0.015 0.191 0.103], Final Value = $3929241.72, Sharpe Ratio = 1.07
#
#
# Simulation Run = 6
# Weights = [0.151 0.146 0.023 0.09  0.093 0.182 0.157 0.061 0.096], Final Value = $4319207.47, Sharpe Ratio = 1.05
#
#
# Simulation Run = 7
# Weights = [0.157 0.135 0.098 0.075 0.162 0.045 0.015 0.141 0.172], Final Value = $3096753.44, Sharpe Ratio = 0.89
#
#
# Simulation Run = 8
# Weights = [0.149 0.161 0.082 0.045 0.012 0.082 0.193 0.076 0.199], Final Value = $3159829.90, Sharpe Ratio = 0.82
#
#
# Simulation Run = 9
# Weights = [0.198 0.181 0.139 0.019 0.105 0.107 0.038 0.093 0.12 ], Final Value = $3513586.69, Sharpe Ratio = 0.92
#
#
# Simulation Run = 10
# Weights = [0.091 0.002 0.022 0.17  0.056 0.144 0.205 0.192 0.118], Final Value = $4379677.03, Sharpe Ratio = 1.19
#
#
# Simulation Run = 11
# Weights = [0.168 0.086 0.1   0.106 0.126 0.184 0.13  0.036 0.064], Final Value = $4515546.48, Sharpe Ratio = 1.14
#
#
# Simulation Run = 12
# Weights = [0.087 0.107 0.121 0.139 0.128 0.096 0.101 0.075 0.146], Final Value = $3675992.17, Sharpe Ratio = 1.04
#
#
# Simulation Run = 13
# Weights = [0.071 0.058 0.174 0.063 0.073 0.101 0.125 0.192 0.144], Final Value = $3880857.16, Sharpe Ratio = 1.16
#
#
# Simulation Run = 14
# Weights = [0.06  0.022 0.241 0.055 0.005 0.274 0.156 0.012 0.175], Final Value = $5327385.86, Sharpe Ratio = 1.27
#
#
# Simulation Run = 15
# Weights = [0.149 0.074 0.096 0.117 0.164 0.048 0.033 0.173 0.145], Final Value = $3330373.05, Sharpe Ratio = 1.00
#
#
# Simulation Run = 16
# Weights = [0.157 0.153 0.088 0.138 0.147 0.113 0.041 0.106 0.056], Final Value = $3823980.11, Sharpe Ratio = 1.02
#
#
# Simulation Run = 17
# Weights = [0.21  0.023 0.106 0.015 0.042 0.061 0.208 0.227 0.109], Final Value = $3450282.64, Sharpe Ratio = 1.02
#
#
# Simulation Run = 18
# Weights = [0.091 0.095 0.112 0.109 0.045 0.187 0.086 0.189 0.087], Final Value = $4628329.76, Sharpe Ratio = 1.22
#
#
# Simulation Run = 19
# Weights = [0.21  0.047 0.059 0.114 0.146 0.003 0.217 0.141 0.064], Final Value = $2962274.74, Sharpe Ratio = 0.92
#
#
# Simulation Run = 20
# Weights = [0.129 0.145 0.002 0.168 0.11  0.148 0.019 0.109 0.169], Final Value = $3982059.94, Sharpe Ratio = 0.97
#
#
# Simulation Run = 21
# Weights = [0.194 0.146 0.158 0.006 0.045 0.08  0.062 0.145 0.164], Final Value = $3263326.04, Sharpe Ratio = 0.89
#
#
# Simulation Run = 22
# Weights = [0.137 0.034 0.171 0.08  0.092 0.151 0.14  0.146 0.049], Final Value = $4429340.09, Sharpe Ratio = 1.26
#
#
# Simulation Run = 23
# Weights = [0.116 0.002 0.16  0.152 0.012 0.218 0.207 0.12  0.014], Final Value = $5099909.33, Sharpe Ratio = 1.32
#
#
# Simulation Run = 24
# Weights = [0.255 0.096 0.049 0.007 0.14  0.07  0.13  0.053 0.2  ], Final Value = $3144872.08, Sharpe Ratio = 0.81
#
#
# Simulation Run = 25
# Weights = [0.036 0.178 0.063 0.061 0.179 0.173 0.214 0.062 0.033], Final Value = $4498404.31, Sharpe Ratio = 1.14
#
#
# Simulation Run = 26
# Weights = [0.19  0.185 0.127 0.09  0.042 0.115 0.083 0.043 0.124], Final Value = $3488864.59, Sharpe Ratio = 0.88
#
#
# Simulation Run = 27
# Weights = [0.089 0.046 0.051 0.067 0.18  0.132 0.145 0.176 0.113], Final Value = $4291189.82, Sharpe Ratio = 1.21
#
#
# Simulation Run = 28
# Weights = [0.281 0.286 0.021 0.025 0.152 0.091 0.035 0.037 0.072], Final Value = $3100615.75, Sharpe Ratio = 0.67
#
#
# Simulation Run = 29
# Weights = [0.183 0.088 0.099 0.079 0.089 0.081 0.113 0.111 0.156], Final Value = $3422770.78, Sharpe Ratio = 0.96
#
#
# Simulation Run = 30
# Weights = [0.006 0.169 0.025 0.228 0.041 0.209 0.074 0.067 0.18 ], Final Value = $4552826.72, Sharpe Ratio = 1.02
#
#
# Simulation Run = 31
# Weights = [0.191 0.037 0.118 0.029 0.149 0.116 0.067 0.205 0.089], Final Value = $4062844.81, Sharpe Ratio = 1.16
#
#
# Simulation Run = 32
# Weights = [0.098 0.164 0.119 0.12  0.104 0.051 0.054 0.129 0.16 ], Final Value = $3127753.17, Sharpe Ratio = 0.90
#
#
# Simulation Run = 33
# Weights = [0.158 0.026 0.108 0.114 0.096 0.119 0.1   0.147 0.132], Final Value = $4007717.64, Sharpe Ratio = 1.14
#
#
# Simulation Run = 34
# Weights = [0.086 0.098 0.213 0.043 0.214 0.198 0.096 0.032 0.019], Final Value = $4885907.70, Sharpe Ratio = 1.27
#
#
# Simulation Run = 35
# Weights = [0.089 0.149 0.078 0.011 0.108 0.133 0.165 0.137 0.13 ], Final Value = $3965705.90, Sharpe Ratio = 1.07
#
#
# Simulation Run = 36
# Weights = [0.024 0.069 0.026 0.171 0.283 0.075 0.001 0.274 0.078], Final Value = $4023106.87, Sharpe Ratio = 1.14
#
#
# Simulation Run = 37
# Weights = [0.07  0.135 0.108 0.005 0.049 0.157 0.138 0.156 0.183], Final Value = $4126857.39, Sharpe Ratio = 1.09
#
#
# Simulation Run = 38
# Weights = [0.136 0.046 0.107 0.162 0.145 0.038 0.044 0.209 0.111], Final Value = $3374115.12, Sharpe Ratio = 1.05
#
#
# Simulation Run = 39
# Weights = [0.17  0.116 0.03  0.098 0.195 0.137 0.052 0.115 0.087], Final Value = $4098277.75, Sharpe Ratio = 1.06
#
#
# Simulation Run = 40
# Weights = [0.09  0.139 0.071 0.137 0.199 0.072 0.131 0.111 0.05 ], Final Value = $3616339.07, Sharpe Ratio = 1.04
#
#
# Simulation Run = 41
# Weights = [0.105 0.162 0.001 0.121 0.072 0.184 0.061 0.108 0.186], Final Value = $4245775.89, Sharpe Ratio = 1.00
#
#
# Simulation Run = 42
# Weights = [0.156 0.116 0.108 0.055 0.168 0.045 0.086 0.117 0.149], Final Value = $3161649.58, Sharpe Ratio = 0.93
#
#
# Simulation Run = 43
# Weights = [0.051 0.041 0.203 0.061 0.23  0.038 0.252 0.065 0.061], Final Value = $3541930.50, Sharpe Ratio = 1.12
#
#
# Simulation Run = 44
# Weights = [0.163 0.181 0.083 0.029 0.066 0.004 0.162 0.142 0.169], Final Value = $2533382.37, Sharpe Ratio = 0.73
#
#
# Simulation Run = 45
# Weights = [0.07  0.121 0.004 0.06  0.167 0.163 0.12  0.132 0.163], Final Value = $4319556.39, Sharpe Ratio = 1.10
#
#
# Simulation Run = 46
# Weights = [0.189 0.112 0.105 0.201 0.033 0.077 0.024 0.129 0.13 ], Final Value = $3337834.78, Sharpe Ratio = 0.90
#
#
# Simulation Run = 47
# Weights = [0.019 0.207 0.165 0.093 0.103 0.014 0.208 0.145 0.047], Final Value = $2980526.18, Sharpe Ratio = 0.91
#
#
# Simulation Run = 48
# Weights = [0.008 0.023 0.115 0.122 0.159 0.105 0.143 0.09  0.235], Final Value = $3939238.74, Sharpe Ratio = 1.11
#
#
# Simulation Run = 49
# Weights = [0.176 0.022 0.065 0.043 0.186 0.144 0.058 0.179 0.127], Final Value = $4329645.09, Sharpe Ratio = 1.17
#
#
# Simulation Run = 50
# Weights = [0.112 0.187 0.004 0.147 0.013 0.163 0.183 0.068 0.123], Final Value = $4000383.39, Sharpe Ratio = 0.94
#
#
# Simulation Run = 51
# Weights = [0.004 0.173 0.17  0.14  0.063 0.127 0.159 0.055 0.109], Final Value = $3916267.18, Sharpe Ratio = 1.05
#
#
# Simulation Run = 52
# Weights = [0.12  0.019 0.224 0.173 0.094 0.144 0.095 0.091 0.041], Final Value = $4410135.46, Sharpe Ratio = 1.25
#
#
# Simulation Run = 53
# Weights = [0.154 0.249 0.013 0.04  0.14  0.016 0.001 0.143 0.244], Final Value = $2461098.25, Sharpe Ratio = 0.61
#
#
# Simulation Run = 54
# Weights = [0.161 0.193 0.15  0.033 0.177 0.107 0.134 0.031 0.014], Final Value = $3716795.32, Sharpe Ratio = 1.00
#
#
# Simulation Run = 55
# Weights = [0.174 0.172 0.178 0.021 0.028 0.095 0.133 0.102 0.097], Final Value = $3420725.49, Sharpe Ratio = 0.93
#
#
# Simulation Run = 56
# Weights = [0.181 0.049 0.12  0.082 0.108 0.15  0.163 0.091 0.055], Final Value = $4298892.96, Sharpe Ratio = 1.16
#
#
# Simulation Run = 57
# Weights = [0.108 0.1   0.151 0.138 0.188 0.002 0.192 0.026 0.095], Final Value = $2901707.73, Sharpe Ratio = 0.91
#
#
# Simulation Run = 58
# Weights = [0.219 0.066 0.084 0.174 0.21  0.026 0.038 0.154 0.029], Final Value = $3255153.16, Sharpe Ratio = 0.97
#
#
# Simulation Run = 59
# Weights = [0.168 0.073 0.129 0.18  0.042 0.019 0.158 0.103 0.127], Final Value = $2906468.38, Sharpe Ratio = 0.88
#
#
# Simulation Run = 60
# Weights = [0.01  0.109 0.13  0.121 0.166 0.102 0.146 0.117 0.099], Final Value = $3959786.47, Sharpe Ratio = 1.14
#
#
# Simulation Run = 61
# Weights = [0.132 0.049 0.039 0.119 0.135 0.109 0.13  0.154 0.134], Final Value = $3924100.87, Sharpe Ratio = 1.10
#
#
# Simulation Run = 62
# Weights = [0.089 0.149 0.014 0.128 0.224 0.191 0.137 0.007 0.06 ], Final Value = $4613758.36, Sharpe Ratio = 1.10
#
#
# Simulation Run = 63
# Weights = [0.045 0.197 0.038 0.124 0.055 0.073 0.184 0.151 0.134], Final Value = $3327765.95, Sharpe Ratio = 0.90
#
#
# Simulation Run = 64
# Weights = [0.126 0.139 0.151 0.009 0.136 0.078 0.146 0.065 0.151], Final Value = $3384834.69, Sharpe Ratio = 0.97
#
#
# Simulation Run = 65
# Weights = [0.093 0.098 0.108 0.159 0.157 0.178 0.017 0.172 0.017], Final Value = $4735761.25, Sharpe Ratio = 1.24
#
#
# Simulation Run = 66
# Weights = [0.103 0.126 0.056 0.076 0.166 0.146 0.081 0.097 0.149], Final Value = $4118933.29, Sharpe Ratio = 1.08
#
#
# Simulation Run = 67
# Weights = [0.181 0.06  0.023 0.164 0.165 0.004 0.073 0.162 0.169], Final Value = $2859508.14, Sharpe Ratio = 0.86
#
#
# Simulation Run = 68
# Weights = [0.169 0.15  0.189 0.118 0.029 0.15  0.009 0.115 0.072], Final Value = $4034895.47, Sharpe Ratio = 1.04
#
#
# Simulation Run = 69
# Weights = [0.098 0.208 0.187 0.076 0.034 0.205 0.049 0.134 0.009], Final Value = $4624477.18, Sharpe Ratio = 1.15
#
#
# Simulation Run = 70
# Weights = [0.005 0.227 0.101 0.122 0.104 0.086 0.109 0.192 0.055], Final Value = $3642633.58, Sharpe Ratio = 1.00
#
#
# Simulation Run = 71
# Weights = [0.108 0.122 0.218 0.134 0.109 0.037 0.167 0.002 0.105], Final Value = $3078193.67, Sharpe Ratio = 0.92
#
#
# Simulation Run = 72
# Weights = [0.082 0.014 0.106 0.019 0.321 0.096 0.003 0.34  0.019], Final Value = $4434108.88, Sharpe Ratio = 1.27
#
#
# Simulation Run = 73
# Weights = [0.017 0.12  0.045 0.171 0.237 0.112 0.124 0.057 0.116], Final Value = $4015294.98, Sharpe Ratio = 1.07
#
#
# Simulation Run = 74
# Weights = [0.094 0.143 0.152 0.091 0.168 0.    0.112 0.178 0.062], Final Value = $2955550.64, Sharpe Ratio = 0.96
#
#
# Simulation Run = 75
# Weights = [0.181 0.017 0.054 0.092 0.149 0.236 0.044 0.051 0.176], Final Value = $4980047.87, Sharpe Ratio = 1.16
#
#
# Simulation Run = 76
# Weights = [0.082 0.019 0.135 0.205 0.201 0.206 0.136 0.011 0.005], Final Value = $5112241.55, Sharpe Ratio = 1.29
#
#
# Simulation Run = 77
# Weights = [0.235 0.1   0.159 0.056 0.035 0.019 0.211 0.016 0.169], Final Value = $2624595.15, Sharpe Ratio = 0.73
#
#
# Simulation Run = 78
# Weights = [0.166 0.109 0.129 0.167 0.016 0.164 0.021 0.055 0.173], Final Value = $4045559.10, Sharpe Ratio = 0.99
#
#
# Simulation Run = 79
# Weights = [0.089 0.137 0.149 0.076 0.217 0.076 0.118 0.136 0.003], Final Value = $3767766.66, Sharpe Ratio = 1.12
#
#
# Simulation Run = 80
# Weights = [0.101 0.158 0.19  0.06  0.057 0.176 0.137 0.084 0.037], Final Value = $4399208.09, Sharpe Ratio = 1.16
#
#
# Simulation Run = 81
# Weights = [0.039 0.01  0.175 0.087 0.195 0.226 0.016 0.005 0.247], Final Value = $5003246.23, Sharpe Ratio = 1.21
#
#
# Simulation Run = 82
# Weights = [0.077 0.079 0.203 0.024 0.182 0.145 0.176 0.033 0.081], Final Value = $4320940.06, Sharpe Ratio = 1.21
#
#
# Simulation Run = 83
# Weights = [0.072 0.004 0.127 0.138 0.022 0.131 0.17  0.166 0.169], Final Value = $4164069.06, Sharpe Ratio = 1.18
#
#
# Simulation Run = 84
# Weights = [0.097 0.077 0.084 0.123 0.17  0.065 0.098 0.204 0.081], Final Value = $3669897.87, Sharpe Ratio = 1.11
#
#
# Simulation Run = 85
# Weights = [0.187 0.12  0.106 0.016 0.127 0.144 0.147 0.049 0.105], Final Value = $3995215.06, Sharpe Ratio = 1.04
#
#
# Simulation Run = 86
# Weights = [0.17  0.045 0.113 0.123 0.097 0.201 0.008 0.039 0.205], Final Value = $4517065.49, Sharpe Ratio = 1.09
#
#
# Simulation Run = 87
# Weights = [0.133 0.213 0.11  0.073 0.081 0.029 0.025 0.184 0.151], Final Value = $2811671.10, Sharpe Ratio = 0.79
#
#
# Simulation Run = 88
# Weights = [0.041 0.215 0.062 0.019 0.276 0.087 0.107 0.151 0.042], Final Value = $3767252.07, Sharpe Ratio = 1.03
#
#
# Simulation Run = 89
# Weights = [0.181 0.043 0.054 0.025 0.264 0.182 0.011 0.053 0.186], Final Value = $4519299.10, Sharpe Ratio = 1.09
#
#
# Simulation Run = 90
# Weights = [0.078 0.162 0.159 0.04  0.187 0.06  0.086 0.136 0.092], Final Value = $3422701.50, Sharpe Ratio = 1.02
#
#
# Simulation Run = 91
# Weights = [0.121 0.035 0.167 0.031 0.011 0.234 0.181 0.083 0.137], Final Value = $4957727.79, Sharpe Ratio = 1.24
#
#
# Simulation Run = 92
# Weights = [0.019 0.19  0.076 0.172 0.093 0.202 0.03  0.004 0.215], Final Value = $4379724.39, Sharpe Ratio = 0.98
#
#
# Simulation Run = 93
# Weights = [0.055 0.146 0.132 0.131 0.039 0.039 0.183 0.127 0.147], Final Value = $3071496.47, Sharpe Ratio = 0.91
#
#
# Simulation Run = 94
# Weights = [0.1   0.035 0.194 0.171 0.197 0.099 0.044 0.034 0.124], Final Value = $3916904.63, Sharpe Ratio = 1.12
#
#
# Simulation Run = 95
# Weights = [0.243 0.014 0.08  0.066 0.323 0.025 0.019 0.197 0.033], Final Value = $3443864.48, Sharpe Ratio = 1.02
#
#
# Simulation Run = 96
# Weights = [0.115 0.006 0.024 0.255 0.129 0.058 0.171 0.174 0.068], Final Value = $3681528.53, Sharpe Ratio = 1.09
#
#
# Simulation Run = 97
# Weights = [0.097 0.024 0.188 0.099 0.12  0.025 0.196 0.118 0.132], Final Value = $3233862.30, Sharpe Ratio = 1.05
#
#
# Simulation Run = 98
# Weights = [0.079 0.104 0.136 0.113 0.194 0.06  0.105 0.202 0.006], Final Value = $3727749.13, Sharpe Ratio = 1.15
#
#
# Simulation Run = 99
# Weights = [0.196 0.182 0.082 0.097 0.075 0.024 0.104 0.111 0.131], Final Value = $2715994.82, Sharpe Ratio = 0.76
#
#
# Simulation Run = 100
# Weights = [0.023 0.177 0.149 0.189 0.039 0.14  0.029 0.109 0.144], Final Value = $3973942.61, Sharpe Ratio = 1.02
#
#
# Simulation Run = 101
# Weights = [0.011 0.214 0.018 0.229 0.028 0.211 0.181 0.06  0.049], Final Value = $4637910.88, Sharpe Ratio = 1.04
#
#
# Simulation Run = 102
# Weights = [0.08  0.064 0.044 0.166 0.181 0.191 0.104 0.132 0.04 ], Final Value = $4890843.94, Sharpe Ratio = 1.26
#
#
# Simulation Run = 103
# Weights = [0.181 0.03  0.232 0.022 0.089 0.07  0.185 0.171 0.02 ], Final Value = $3708483.28, Sharpe Ratio = 1.14
#
#
# Simulation Run = 104
# Weights = [0.067 0.102 0.192 0.117 0.13  0.076 0.076 0.095 0.145], Final Value = $3558839.33, Sharpe Ratio = 1.06
#
#
# Simulation Run = 105
# Weights = [0.096 0.042 0.067 0.017 0.167 0.182 0.185 0.069 0.173], Final Value = $4572688.17, Sharpe Ratio = 1.18
#
#
# Simulation Run = 106
# Weights = [0.07  0.207 0.092 0.2   0.143 0.133 0.112 0.027 0.016], Final Value = $4006331.31, Sharpe Ratio = 1.02
#
#
# Simulation Run = 107
# Weights = [0.076 0.    0.029 0.064 0.202 0.141 0.085 0.316 0.088], Final Value = $4645551.09, Sharpe Ratio = 1.30
#
#
# Simulation Run = 108
# Weights = [0.144 0.031 0.147 0.072 0.152 0.107 0.045 0.142 0.161], Final Value = $3909458.40, Sharpe Ratio = 1.13
#
#
# Simulation Run = 109
# Weights = [0.181 0.066 0.179 0.229 0.067 0.192 0.059 0.014 0.014], Final Value = $4629098.16, Sharpe Ratio = 1.14
#
#
# Simulation Run = 110
# Weights = [0.056 0.011 0.122 0.094 0.054 0.172 0.18  0.181 0.131], Final Value = $4639269.84, Sharpe Ratio = 1.28
#
#
# Simulation Run = 111
# Weights = [0.099 0.025 0.187 0.185 0.01  0.082 0.146 0.102 0.164], Final Value = $3592580.27, Sharpe Ratio = 1.06
#
#
# Simulation Run = 112
# Weights = [0.121 0.202 0.199 0.084 0.104 0.046 0.072 0.066 0.105], Final Value = $3023817.39, Sharpe Ratio = 0.87
#
#
# Simulation Run = 113
# Weights = [0.192 0.059 0.174 0.165 0.017 0.013 0.135 0.182 0.063], Final Value = $2979662.27, Sharpe Ratio = 0.94
#
#
# Simulation Run = 114
# Weights = [0.14  0.044 0.097 0.014 0.115 0.143 0.078 0.18  0.188], Final Value = $4168556.11, Sharpe Ratio = 1.14
#
#
# Simulation Run = 115
# Weights = [0.175 0.039 0.037 0.204 0.172 0.108 0.069 0.176 0.021], Final Value = $4112727.50, Sharpe Ratio = 1.13
#
#
# Simulation Run = 116
# Weights = [0.014 0.209 0.099 0.064 0.07  0.162 0.082 0.196 0.105], Final Value = $4259382.52, Sharpe Ratio = 1.10
#
#
# Simulation Run = 117
# Weights = [0.161 0.151 0.046 0.027 0.146 0.167 0.066 0.075 0.161], Final Value = $4128476.74, Sharpe Ratio = 1.01
#
#
# Simulation Run = 118
# Weights = [0.079 0.005 0.044 0.164 0.161 0.14  0.185 0.15  0.072], Final Value = $4487586.73, Sharpe Ratio = 1.25
#
#
# Simulation Run = 119
# Weights = [0.248 0.085 0.126 0.015 0.156 0.142 0.042 0.027 0.158], Final Value = $3908390.42, Sharpe Ratio = 0.97
#
#
# Simulation Run = 120
# Weights = [0.171 0.055 0.08  0.077 0.016 0.187 0.132 0.132 0.149], Final Value = $4437135.97, Sharpe Ratio = 1.12
#
#
# Simulation Run = 121
# Weights = [0.092 0.159 0.104 0.064 0.019 0.212 0.077 0.161 0.112], Final Value = $4642265.85, Sharpe Ratio = 1.15
#
#
# Simulation Run = 122
# Weights = [0.014 0.158 0.081 0.164 0.128 0.154 0.046 0.1   0.154], Final Value = $4204997.73, Sharpe Ratio = 1.07
#
#
# Simulation Run = 123
# Weights = [0.074 0.162 0.068 0.008 0.181 0.164 0.157 0.045 0.141], Final Value = $4224328.20, Sharpe Ratio = 1.07
#
#
# Simulation Run = 124
# Weights = [0.139 0.134 0.106 0.165 0.11  0.153 0.023 0.102 0.067], Final Value = $4203319.26, Sharpe Ratio = 1.09
#
#
# Simulation Run = 125
# Weights = [0.151 0.024 0.101 0.163 0.1   0.202 0.181 0.037 0.041], Final Value = $4834800.77, Sharpe Ratio = 1.22
#
#
# Simulation Run = 126
# Weights = [0.085 0.169 0.075 0.156 0.136 0.035 0.132 0.125 0.088], Final Value = $3116684.78, Sharpe Ratio = 0.92
#
#
# Simulation Run = 127
# Weights = [0.127 0.127 0.008 0.25  0.091 0.024 0.107 0.122 0.143], Final Value = $2920194.64, Sharpe Ratio = 0.82
#
#
# Simulation Run = 128
# Weights = [0.149 0.209 0.136 0.074 0.193 0.146 0.031 0.028 0.034], Final Value = $4045205.71, Sharpe Ratio = 1.01
#
#
# Simulation Run = 129
# Weights = [0.094 0.135 0.085 0.158 0.136 0.025 0.183 0.111 0.074], Final Value = $3096107.13, Sharpe Ratio = 0.94
#
#
# Simulation Run = 130
# Weights = [0.198 0.167 0.078 0.059 0.01  0.079 0.12  0.199 0.091], Final Value = $3311615.61, Sharpe Ratio = 0.89
#
#
# Simulation Run = 131
# Weights = [0.11  0.062 0.292 0.086 0.007 0.106 0.062 0.114 0.163], Final Value = $3742417.80, Sharpe Ratio = 1.08
#
#
# Simulation Run = 132
# Weights = [0.165 0.037 0.003 0.278 0.233 0.18  0.046 0.05  0.008], Final Value = $4767218.63, Sharpe Ratio = 1.14
#
#
# Simulation Run = 133
# Weights = [0.054 0.121 0.113 0.159 0.126 0.112 0.114 0.066 0.136], Final Value = $3838896.21, Sharpe Ratio = 1.06
#
#
# Simulation Run = 134
# Weights = [0.091 0.192 0.053 0.1   0.18  0.075 0.097 0.187 0.023], Final Value = $3612131.14, Sharpe Ratio = 1.02
#
#
# Simulation Run = 135
# Weights = [0.082 0.056 0.011 0.164 0.168 0.15  0.18  0.082 0.106], Final Value = $4377046.22, Sharpe Ratio = 1.15
#
#
# Simulation Run = 136
# Weights = [0.139 0.015 0.094 0.151 0.15  0.176 0.114 0.135 0.025], Final Value = $4781197.53, Sharpe Ratio = 1.28
#
#
# Simulation Run = 137
# Weights = [0.119 0.109 0.134 0.079 0.166 0.091 0.041 0.103 0.157], Final Value = $3624457.25, Sharpe Ratio = 1.03
#
#
# Simulation Run = 138
# Weights = [0.132 0.101 0.053 0.159 0.095 0.054 0.167 0.158 0.082], Final Value = $3363111.37, Sharpe Ratio = 0.99
#
#
# Simulation Run = 139
# Weights = [0.041 0.189 0.086 0.152 0.193 0.09  0.051 0.015 0.182], Final Value = $3475426.73, Sharpe Ratio = 0.89
#
#
# Simulation Run = 140
# Weights = [0.058 0.021 0.156 0.082 0.224 0.137 0.013 0.3   0.01 ], Final Value = $4731638.49, Sharpe Ratio = 1.35
#
#
# Simulation Run = 141
# Weights = [0.055 0.088 0.157 0.015 0.191 0.113 0.051 0.184 0.146], Final Value = $4049832.09, Sharpe Ratio = 1.18
#
#
# Simulation Run = 142
# Weights = [0.052 0.176 0.133 0.051 0.132 0.18  0.165 0.016 0.094], Final Value = $4391204.60, Sharpe Ratio = 1.11
#
#
# Simulation Run = 143
# Weights = [0.208 0.14  0.093 0.115 0.062 0.125 0.058 0.128 0.071], Final Value = $3805737.04, Sharpe Ratio = 0.99
#
#
# Simulation Run = 144
# Weights = [0.041 0.193 0.043 0.135 0.139 0.053 0.06  0.167 0.17 ], Final Value = $3192275.59, Sharpe Ratio = 0.88
#
#
# Simulation Run = 145
# Weights = [0.069 0.005 0.083 0.121 0.178 0.182 0.028 0.143 0.19 ], Final Value = $4725837.29, Sharpe Ratio = 1.24
#
#
# Simulation Run = 146
# Weights = [0.137 0.18  0.082 0.174 0.104 0.161 0.017 0.003 0.142], Final Value = $3991988.55, Sharpe Ratio = 0.94
#
#
# Simulation Run = 147
# Weights = [0.01  0.108 0.083 0.2   0.182 0.149 0.055 0.029 0.184], Final Value = $4224745.46, Sharpe Ratio = 1.06
#
#
# Simulation Run = 148
# Weights = [0.079 0.151 0.033 0.166 0.101 0.065 0.155 0.094 0.156], Final Value = $3277006.89, Sharpe Ratio = 0.90
#
#
# Simulation Run = 149
# Weights = [0.191 0.207 0.112 0.03  0.012 0.149 0.083 0.067 0.148], Final Value = $3702321.60, Sharpe Ratio = 0.88
#
#
# Simulation Run = 150
# Weights = [0.004 0.158 0.096 0.143 0.165 0.133 0.064 0.118 0.118], Final Value = $4127927.24, Sharpe Ratio = 1.10
#
#
# Simulation Run = 151
# Weights = [0.119 0.068 0.165 0.001 0.228 0.184 0.054 0.083 0.099], Final Value = $4692754.50, Sharpe Ratio = 1.24
#
#
# Simulation Run = 152
# Weights = [0.19  0.248 0.092 0.014 0.018 0.111 0.027 0.11  0.189], Final Value = $3248412.04, Sharpe Ratio = 0.75
#
#
# Simulation Run = 153
# Weights = [0.107 0.195 0.099 0.061 0.028 0.215 0.131 0.153 0.011], Final Value = $4729505.25, Sharpe Ratio = 1.16
#
#
# Simulation Run = 154
# Weights = [0.122 0.067 0.173 0.115 0.141 0.022 0.118 0.167 0.074], Final Value = $3225552.80, Sharpe Ratio = 1.05
#
#
# Simulation Run = 155
# Weights = [0.121 0.166 0.053 0.076 0.185 0.161 0.13  0.062 0.045], Final Value = $4298255.65, Sharpe Ratio = 1.09
#
#
# Simulation Run = 156
# Weights = [0.092 0.102 0.022 0.192 0.097 0.008 0.185 0.12  0.183], Final Value = $2804733.54, Sharpe Ratio = 0.83
#
#
# Simulation Run = 157
# Weights = [0.046 0.1   0.064 0.298 0.02  0.15  0.118 0.005 0.2  ], Final Value = $4003045.62, Sharpe Ratio = 0.96
#
#
# Simulation Run = 158
# Weights = [0.093 0.103 0.089 0.207 0.192 0.048 0.096 0.017 0.154], Final Value = $3240255.32, Sharpe Ratio = 0.92
#
#
# Simulation Run = 159
# Weights = [0.061 0.16  0.023 0.192 0.135 0.188 0.15  0.084 0.007], Final Value = $4659965.18, Sharpe Ratio = 1.14
#
#
# Simulation Run = 160
# Weights = [0.175 0.093 0.224 0.014 0.213 0.127 0.099 0.015 0.039], Final Value = $4085390.81, Sharpe Ratio = 1.12
#
#
# Simulation Run = 161
# Weights = [0.211 0.121 0.102 0.143 0.081 0.016 0.151 0.063 0.113], Final Value = $2744738.24, Sharpe Ratio = 0.80
#
#
# Simulation Run = 162
# Weights = [0.12  0.206 0.226 0.14  0.016 0.069 0.113 0.022 0.09 ], Final Value = $3133496.98, Sharpe Ratio = 0.85
#
#
# Simulation Run = 163
# Weights = [0.172 0.179 0.027 0.159 0.11  0.129 0.054 0.028 0.142], Final Value = $3665012.09, Sharpe Ratio = 0.88
#
#
# Simulation Run = 164
# Weights = [0.125 0.131 0.115 0.127 0.135 0.106 0.144 0.042 0.076], Final Value = $3755436.24, Sharpe Ratio = 1.04
#
#
# Simulation Run = 165
# Weights = [0.159 0.149 0.033 0.102 0.155 0.045 0.106 0.124 0.127], Final Value = $3107464.58, Sharpe Ratio = 0.88
#
#
# Simulation Run = 166
# Weights = [0.119 0.061 0.188 0.161 0.089 0.08  0.071 0.105 0.127], Final Value = $3609857.96, Sharpe Ratio = 1.07
#
#
# Simulation Run = 167
# Weights = [0.068 0.033 0.015 0.285 0.24  0.152 0.045 0.141 0.021], Final Value = $4703910.63, Sharpe Ratio = 1.21
#
#
# Simulation Run = 168
# Weights = [0.112 0.132 0.103 0.121 0.159 0.012 0.114 0.099 0.148], Final Value = $2863668.94, Sharpe Ratio = 0.87
#
#
# Simulation Run = 169
# Weights = [0.097 0.    0.107 0.102 0.172 0.184 0.038 0.237 0.063], Final Value = $4970460.17, Sharpe Ratio = 1.35
#
#
# Simulation Run = 170
# Weights = [0.132 0.156 0.081 0.05  0.143 0.145 0.048 0.108 0.138], Final Value = $4008571.51, Sharpe Ratio = 1.04
#
#
# Simulation Run = 171
# Weights = [0.06  0.103 0.096 0.158 0.035 0.126 0.106 0.171 0.146], Final Value = $3974302.24, Sharpe Ratio = 1.09
#
#
# Simulation Run = 172
# Weights = [0.115 0.179 0.004 0.021 0.148 0.061 0.1   0.17  0.202], Final Value = $3158559.73, Sharpe Ratio = 0.85
#
#
# Simulation Run = 173
# Weights = [0.042 0.226 0.213 0.13  0.222 0.013 0.06  0.091 0.004], Final Value = $3048129.03, Sharpe Ratio = 0.91
#
#
# Simulation Run = 174
# Weights = [0.176 0.064 0.07  0.155 0.09  0.076 0.192 0.155 0.022], Final Value = $3670837.97, Sharpe Ratio = 1.06
#
#
# Simulation Run = 175
# Weights = [0.001 0.163 0.156 0.122 0.11  0.135 0.078 0.177 0.056], Final Value = $4230127.18, Sharpe Ratio = 1.17
#
#
# Simulation Run = 176
# Weights = [0.055 0.014 0.133 0.058 0.163 0.111 0.202 0.204 0.061], Final Value = $4297390.07, Sharpe Ratio = 1.29
#
#
# Simulation Run = 177
# Weights = [0.026 0.145 0.126 0.007 0.065 0.166 0.164 0.197 0.105], Final Value = $4403909.49, Sharpe Ratio = 1.19
#
#
# Simulation Run = 178
# Weights = [0.102 0.058 0.101 0.13  0.132 0.164 0.051 0.119 0.144], Final Value = $4419781.46, Sharpe Ratio = 1.18
#
#
# Simulation Run = 179
# Weights = [0.13  0.023 0.156 0.117 0.143 0.166 0.147 0.009 0.108], Final Value = $4465886.67, Sharpe Ratio = 1.19
#
#
# Simulation Run = 180
# Weights = [0.008 0.014 0.228 0.236 0.027 0.081 0.148 0.16  0.098], Final Value = $3884067.58, Sharpe Ratio = 1.17
#
#
# Simulation Run = 181
# Weights = [0.024 0.05  0.303 0.147 0.168 0.288 0.006 0.002 0.012], Final Value = $5848343.31, Sharpe Ratio = 1.35
#
#
# Simulation Run = 182
# Weights = [0.178 0.124 0.162 0.061 0.016 0.075 0.024 0.172 0.188], Final Value = $3241213.86, Sharpe Ratio = 0.89
#
#
# Simulation Run = 183
# Weights = [0.093 0.039 0.084 0.189 0.193 0.119 0.084 0.148 0.051], Final Value = $4274202.50, Sharpe Ratio = 1.21
#
#
# Simulation Run = 184
# Weights = [0.138 0.132 0.109 0.121 0.14  0.143 0.022 0.124 0.072], Final Value = $4153002.05, Sharpe Ratio = 1.10
#
#
# Simulation Run = 185
# Weights = [0.157 0.14  0.006 0.024 0.196 0.061 0.123 0.175 0.118], Final Value = $3361887.55, Sharpe Ratio = 0.94
#
#
# Simulation Run = 186
# Weights = [0.045 0.162 0.111 0.03  0.113 0.154 0.156 0.049 0.18 ], Final Value = $4063533.55, Sharpe Ratio = 1.04
#
#
# Simulation Run = 187
# Weights = [0.058 0.045 0.216 0.198 0.085 0.006 0.235 0.079 0.08 ], Final Value = $3086260.87, Sharpe Ratio = 1.00
#
#
# Simulation Run = 188
# Weights = [0.208 0.01  0.029 0.108 0.013 0.157 0.109 0.337 0.029], Final Value = $4522332.96, Sharpe Ratio = 1.18
#
#
# Simulation Run = 189
# Weights = [0.197 0.068 0.128 0.062 0.147 0.155 0.022 0.06  0.159], Final Value = $4149603.23, Sharpe Ratio = 1.06
#
#
# Simulation Run = 190
# Weights = [0.042 0.132 0.193 0.087 0.017 0.153 0.181 0.05  0.146], Final Value = $4088933.48, Sharpe Ratio = 1.08
#
#
# Simulation Run = 191
# Weights = [0.085 0.064 0.124 0.062 0.146 0.056 0.156 0.161 0.146], Final Value = $3479616.79, Sharpe Ratio = 1.08
#
#
# Simulation Run = 192
# Weights = [0.186 0.016 0.022 0.029 0.208 0.264 0.251 0.    0.024], Final Value = $5462256.93, Sharpe Ratio = 1.23
#
#
# Simulation Run = 193
# Weights = [0.064 0.089 0.1   0.117 0.162 0.116 0.132 0.051 0.168], Final Value = $3900373.61, Sharpe Ratio = 1.07
#
#
# Simulation Run = 194
# Weights = [0.085 0.042 0.162 0.089 0.176 0.179 0.07  0.175 0.021], Final Value = $4881989.86, Sharpe Ratio = 1.35
#
#
# Simulation Run = 195
# Weights = [0.125 0.095 0.105 0.031 0.306 0.079 0.093 0.162 0.004], Final Value = $3932933.74, Sharpe Ratio = 1.15
#
#
# Simulation Run = 196
# Weights = [0.256 0.042 0.03  0.056 0.109 0.253 0.019 0.186 0.049], Final Value = $5237758.79, Sharpe Ratio = 1.18
#
#
# Simulation Run = 197
# Weights = [0.043 0.143 0.003 0.132 0.134 0.015 0.215 0.138 0.178], Final Value = $2901627.36, Sharpe Ratio = 0.84
#
#
# Simulation Run = 198
# Weights = [0.134 0.011 0.193 0.173 0.088 0.17  0.143 0.026 0.063], Final Value = $4551528.88, Sharpe Ratio = 1.22
#
#
# Simulation Run = 199
# Weights = [0.145 0.073 0.13  0.055 0.042 0.146 0.105 0.128 0.176], Final Value = $4042730.34, Sharpe Ratio = 1.09
#
#
# Simulation Run = 200
# Weights = [0.05  0.217 0.123 0.007 0.12  0.071 0.074 0.189 0.15 ], Final Value = $3334162.64, Sharpe Ratio = 0.93
#
#
# Simulation Run = 201
# Weights = [0.191 0.018 0.068 0.183 0.058 0.122 0.053 0.113 0.194], Final Value = $3848222.72, Sharpe Ratio = 1.01
#
#
# Simulation Run = 202
# Weights = [0.257 0.048 0.114 0.069 0.113 0.123 0.098 0.154 0.024], Final Value = $4044831.19, Sharpe Ratio = 1.09
#
#
# Simulation Run = 203
# Weights = [0.138 0.147 0.056 0.137 0.145 0.193 0.071 0.068 0.045], Final Value = $4574461.89, Sharpe Ratio = 1.11
#
#
# Simulation Run = 204
# Weights = [0.15  0.147 0.099 0.108 0.082 0.096 0.108 0.011 0.199], Final Value = $3342037.10, Sharpe Ratio = 0.86
#
#
# Simulation Run = 205
# Weights = [0.211 0.058 0.055 0.125 0.086 0.049 0.213 0.129 0.075], Final Value = $3277254.35, Sharpe Ratio = 0.95
#
#
# Simulation Run = 206
# Weights = [0.119 0.201 0.036 0.088 0.009 0.055 0.162 0.078 0.253], Final Value = $2784089.73, Sharpe Ratio = 0.69
#
#
# Simulation Run = 207
# Weights = [0.084 0.156 0.008 0.156 0.042 0.122 0.107 0.171 0.155], Final Value = $3781181.60, Sharpe Ratio = 0.97
#
#
# Simulation Run = 208
# Weights = [0.102 0.145 0.02  0.069 0.142 0.141 0.142 0.133 0.107], Final Value = $4087214.48, Sharpe Ratio = 1.08
#
#
# Simulation Run = 209
# Weights = [0.063 0.03  0.13  0.161 0.17  0.09  0.157 0.095 0.104], Final Value = $3924801.78, Sharpe Ratio = 1.17
#
#
# Simulation Run = 210
# Weights = [0.144 0.273 0.043 0.159 0.061 0.029 0.01  0.062 0.219], Final Value = $2456648.44, Sharpe Ratio = 0.57
#
#
# Simulation Run = 211
# Weights = [0.11  0.163 0.105 0.085 0.179 0.114 0.004 0.183 0.056], Final Value = $3959803.26, Sharpe Ratio = 1.09
#
#
# Simulation Run = 212
# Weights = [0.031 0.119 0.158 0.167 0.026 0.099 0.12  0.126 0.154], Final Value = $3689293.49, Sharpe Ratio = 1.04
#
#
# Simulation Run = 213
# Weights = [0.194 0.152 0.05  0.002 0.283 0.067 0.004 0.237 0.011], Final Value = $3629484.64, Sharpe Ratio = 1.00
#
#
# Simulation Run = 214
# Weights = [0.135 0.109 0.029 0.144 0.051 0.109 0.001 0.239 0.182], Final Value = $3719507.90, Sharpe Ratio = 0.98
#
#
# Simulation Run = 215
# Weights = [0.202 0.253 0.154 0.005 0.008 0.066 0.004 0.049 0.26 ], Final Value = $2651513.69, Sharpe Ratio = 0.59
#
#
# Simulation Run = 216
# Weights = [0.155 0.142 0.047 0.045 0.199 0.079 0.114 0.047 0.171], Final Value = $3355893.90, Sharpe Ratio = 0.90
#
#
# Simulation Run = 217
# Weights = [0.167 0.144 0.165 0.121 0.035 0.059 0.073 0.176 0.06 ], Final Value = $3281323.94, Sharpe Ratio = 0.96
#
#
# Simulation Run = 218
# Weights = [0.163 0.225 0.047 0.074 0.015 0.251 0.018 0.196 0.012], Final Value = $4936048.95, Sharpe Ratio = 1.08
#
#
# Simulation Run = 219
# Weights = [0.114 0.003 0.162 0.114 0.058 0.17  0.146 0.126 0.105], Final Value = $4574457.64, Sharpe Ratio = 1.27
#
#
# Simulation Run = 220
# Weights = [0.161 0.04  0.068 0.109 0.156 0.06  0.115 0.133 0.159], Final Value = $3427188.12, Sharpe Ratio = 1.01
#
#
# Simulation Run = 221
# Weights = [0.16  0.059 0.13  0.078 0.139 0.184 0.051 0.11  0.088], Final Value = $4616114.98, Sharpe Ratio = 1.21
#
#
# Simulation Run = 222
# Weights = [0.18  0.11  0.043 0.113 0.176 0.146 0.12  0.048 0.065], Final Value = $4142398.27, Sharpe Ratio = 1.06
#
#
# Simulation Run = 223
# Weights = [0.064 0.242 0.121 0.034 0.004 0.007 0.073 0.253 0.204], Final Value = $2537920.99, Sharpe Ratio = 0.69
#
#
# Simulation Run = 224
# Weights = [0.057 0.274 0.071 0.102 0.232 0.037 0.139 0.085 0.002], Final Value = $3143857.83, Sharpe Ratio = 0.86
#
#
# Simulation Run = 225
# Weights = [0.159 0.098 0.096 0.102 0.162 0.061 0.043 0.163 0.116], Final Value = $3416034.67, Sharpe Ratio = 1.00
#
#
# Simulation Run = 226
# Weights = [0.034 0.076 0.143 0.098 0.042 0.136 0.13  0.133 0.207], Final Value = $4051445.10, Sharpe Ratio = 1.11
#
#
# Simulation Run = 227
# Weights = [0.157 0.124 0.157 0.127 0.073 0.014 0.107 0.089 0.151], Final Value = $2758261.73, Sharpe Ratio = 0.83
#
#
# Simulation Run = 228
# Weights = [0.095 0.121 0.056 0.06  0.176 0.152 0.044 0.166 0.13 ], Final Value = $4278265.78, Sharpe Ratio = 1.13
#
#
# Simulation Run = 229
# Weights = [0.298 0.208 0.163 0.049 0.055 0.032 0.055 0.049 0.093], Final Value = $2600371.70, Sharpe Ratio = 0.65
#
#
# Simulation Run = 230
# Weights = [0.154 0.049 0.157 0.084 0.01  0.044 0.135 0.187 0.179], Final Value = $3152267.93, Sharpe Ratio = 0.96
#
#
# Simulation Run = 231
# Weights = [0.185 0.072 0.164 0.071 0.238 0.045 0.055 0.163 0.006], Final Value = $3533330.90, Sharpe Ratio = 1.08
#
#
# Simulation Run = 232
# Weights = [0.12  0.079 0.117 0.113 0.071 0.141 0.109 0.114 0.136], Final Value = $4091826.22, Sharpe Ratio = 1.12
#
#
# Simulation Run = 233
# Weights = [0.226 0.03  0.064 0.059 0.101 0.094 0.169 0.074 0.181], Final Value = $3552523.08, Sharpe Ratio = 0.96
#
#
# Simulation Run = 234
# Weights = [0.182 0.162 0.107 0.118 0.141 0.032 0.041 0.117 0.101], Final Value = $2962152.87, Sharpe Ratio = 0.85
#
#
# Simulation Run = 235
# Weights = [0.142 0.14  0.054 0.134 0.084 0.091 0.147 0.088 0.119], Final Value = $3493205.65, Sharpe Ratio = 0.95
#
#
# Simulation Run = 236
# Weights = [0.1   0.12  0.143 0.124 0.076 0.101 0.088 0.055 0.193], Final Value = $3549469.65, Sharpe Ratio = 0.97
#
#
# Simulation Run = 237
# Weights = [0.032 0.198 0.126 0.09  0.058 0.052 0.113 0.113 0.218], Final Value = $3011922.40, Sharpe Ratio = 0.82
#
#
# Simulation Run = 238
# Weights = [0.118 0.062 0.104 0.089 0.191 0.132 0.135 0.119 0.05 ], Final Value = $4291998.58, Sharpe Ratio = 1.21
#
#
# Simulation Run = 239
# Weights = [0.044 0.031 0.119 0.18  0.127 0.058 0.16  0.155 0.125], Final Value = $3629071.23, Sharpe Ratio = 1.12
#
#
# Simulation Run = 240
# Weights = [0.16  0.1   0.17  0.195 0.077 0.193 0.055 0.018 0.034], Final Value = $4576313.68, Sharpe Ratio = 1.13
#
#
# Simulation Run = 241
# Weights = [0.143 0.069 0.156 0.054 0.16  0.19  0.056 0.029 0.142], Final Value = $4555534.42, Sharpe Ratio = 1.16
#
#
# Simulation Run = 242
# Weights = [0.059 0.166 0.203 0.002 0.064 0.216 0.109 0.117 0.063], Final Value = $4793171.85, Sharpe Ratio = 1.23
#
#
# Simulation Run = 243
# Weights = [0.03  0.114 0.126 0.104 0.118 0.155 0.165 0.077 0.111], Final Value = $4316940.57, Sharpe Ratio = 1.16
#
#
# Simulation Run = 244
# Weights = [0.113 0.081 0.114 0.161 0.155 0.092 0.141 0.025 0.117], Final Value = $3690299.74, Sharpe Ratio = 1.04
#
#
# Simulation Run = 245
# Weights = [0.038 0.045 0.138 0.023 0.123 0.132 0.133 0.163 0.206], Final Value = $4162681.55, Sharpe Ratio = 1.18
#
#
# Simulation Run = 246
# Weights = [0.094 0.039 0.198 0.094 0.218 0.19  0.096 0.008 0.063], Final Value = $4840387.29, Sharpe Ratio = 1.27
#
#
# Simulation Run = 247
# Weights = [0.177 0.228 0.076 0.129 0.048 0.097 0.037 0.121 0.087], Final Value = $3359379.61, Sharpe Ratio = 0.84
#
#
# Simulation Run = 248
# Weights = [0.045 0.24  0.117 0.22  0.041 0.014 0.051 0.023 0.248], Final Value = $2438778.99, Sharpe Ratio = 0.60
#
#
# Simulation Run = 249
# Weights = [0.169 0.027 0.023 0.171 0.163 0.053 0.074 0.166 0.155], Final Value = $3416432.62, Sharpe Ratio = 1.00
#
#
# Simulation Run = 250
# Weights = [0.221 0.229 0.102 0.025 0.062 0.02  0.14  0.195 0.005], Final Value = $2786084.80, Sharpe Ratio = 0.77
#
#
# Simulation Run = 251
# Weights = [0.2   0.042 0.11  0.148 0.087 0.031 0.203 0.068 0.11 ], Final Value = $3079307.85, Sharpe Ratio = 0.92
#
#
# Simulation Run = 252
# Weights = [0.103 0.149 0.171 0.157 0.132 0.005 0.125 0.088 0.068], Final Value = $2874053.39, Sharpe Ratio = 0.90
#
#
# Simulation Run = 253
# Weights = [0.166 0.014 0.185 0.145 0.103 0.095 0.159 0.106 0.028], Final Value = $3934870.55, Sharpe Ratio = 1.17
#
#
# Simulation Run = 254
# Weights = [0.326 0.079 0.016 0.118 0.007 0.13  0.166 0.119 0.038], Final Value = $3806456.41, Sharpe Ratio = 0.90
#
#
# Simulation Run = 255
# Weights = [0.139 0.111 0.178 0.058 0.103 0.213 0.103 0.066 0.028], Final Value = $4829165.55, Sharpe Ratio = 1.22
#
#
# Simulation Run = 256
# Weights = [0.182 0.1   0.009 0.208 0.188 0.061 0.007 0.236 0.01 ], Final Value = $3610741.13, Sharpe Ratio = 1.01
#
#
# Simulation Run = 257
# Weights = [0.136 0.117 0.179 0.17  0.028 0.047 0.032 0.147 0.145], Final Value = $3108856.20, Sharpe Ratio = 0.91
#
#
# Simulation Run = 258
# Weights = [0.061 0.095 0.225 0.135 0.107 0.028 0.059 0.063 0.227], Final Value = $2973651.44, Sharpe Ratio = 0.90
#
#
# Simulation Run = 259
# Weights = [0.099 0.015 0.132 0.112 0.04  0.131 0.172 0.193 0.106], Final Value = $4235557.09, Sharpe Ratio = 1.23
#
#
# Simulation Run = 260
# Weights = [0.185 0.096 0.199 0.041 0.144 0.099 0.013 0.167 0.056], Final Value = $3824542.18, Sharpe Ratio = 1.10
#
#
# Simulation Run = 261
# Weights = [0.219 0.158 0.087 0.039 0.147 0.205 0.017 0.017 0.112], Final Value = $4422779.68, Sharpe Ratio = 1.00
#
#
# Simulation Run = 262
# Weights = [0.001 0.007 0.148 0.158 0.11  0.139 0.248 0.171 0.017], Final Value = $4640276.64, Sharpe Ratio = 1.33
#
#
# Simulation Run = 263
# Weights = [0.129 0.062 0.067 0.128 0.091 0.183 0.095 0.121 0.125], Final Value = $4539891.48, Sharpe Ratio = 1.17
#
#
# Simulation Run = 264
# Weights = [0.099 0.174 0.073 0.151 0.067 0.102 0.038 0.202 0.094], Final Value = $3686489.99, Sharpe Ratio = 1.00
#
#
# Simulation Run = 265
# Weights = [0.133 0.129 0.206 0.014 0.117 0.04  0.17  0.111 0.079], Final Value = $3182377.58, Sharpe Ratio = 0.98
#
#
# Simulation Run = 266
# Weights = [0.106 0.083 0.173 0.139 0.045 0.154 0.007 0.197 0.096], Final Value = $4332165.91, Sharpe Ratio = 1.19
#
#
# Simulation Run = 267
# Weights = [0.135 0.024 0.136 0.155 0.154 0.133 0.097 0.155 0.012], Final Value = $4411821.97, Sharpe Ratio = 1.26
#
#
# Simulation Run = 268
# Weights = [0.028 0.084 0.151 0.176 0.173 0.042 0.156 0.102 0.088], Final Value = $3460968.50, Sharpe Ratio = 1.07
#
#
# Simulation Run = 269
# Weights = [0.135 0.146 0.165 0.093 0.186 0.092 0.045 0.107 0.032], Final Value = $3752414.32, Sharpe Ratio = 1.07
#
#
# Simulation Run = 270
# Weights = [0.071 0.125 0.14  0.142 0.182 0.029 0.164 0.047 0.101], Final Value = $3145237.84, Sharpe Ratio = 0.96
#
#
# Simulation Run = 271
# Weights = [0.016 0.184 0.073 0.11  0.118 0.099 0.091 0.126 0.182], Final Value = $3609973.64, Sharpe Ratio = 0.96
#
#
# Simulation Run = 272
# Weights = [0.158 0.111 0.033 0.152 0.166 0.105 0.08  0.17  0.024], Final Value = $3939716.97, Sharpe Ratio = 1.08
#
#
# Simulation Run = 273
# Weights = [0.089 0.165 0.108 0.035 0.207 0.06  0.209 0.122 0.005], Final Value = $3535981.92, Sharpe Ratio = 1.05
#
#
# Simulation Run = 274
# Weights = [0.024 0.055 0.181 0.219 0.098 0.004 0.25  0.102 0.066], Final Value = $3135355.26, Sharpe Ratio = 1.01
#
#
# Simulation Run = 275
# Weights = [0.061 0.196 0.181 0.175 0.165 0.037 0.056 0.074 0.054], Final Value = $3166572.91, Sharpe Ratio = 0.93
#
#
# Simulation Run = 276
# Weights = [0.099 0.142 0.045 0.022 0.09  0.167 0.214 0.208 0.012], Final Value = $4492165.65, Sharpe Ratio = 1.19
#
#
# Simulation Run = 277
# Weights = [0.046 0.207 0.066 0.133 0.073 0.074 0.193 0.099 0.109], Final Value = $3333399.68, Sharpe Ratio = 0.90
#
#
# Simulation Run = 278
# Weights = [0.104 0.141 0.116 0.153 0.131 0.032 0.039 0.161 0.123], Final Value = $3097376.81, Sharpe Ratio = 0.93
#
#
# Simulation Run = 279
# Weights = [0.15  0.129 0.028 0.164 0.033 0.187 0.129 0.119 0.062], Final Value = $4442200.74, Sharpe Ratio = 1.08
#
#
# Simulation Run = 280
# Weights = [0.009 0.194 0.112 0.009 0.18  0.167 0.089 0.02  0.221], Final Value = $4141305.89, Sharpe Ratio = 1.00
#
#
# Simulation Run = 281
# Weights = [0.188 0.093 0.175 0.08  0.077 0.033 0.15  0.069 0.135], Final Value = $2966438.60, Sharpe Ratio = 0.89
#
#
# Simulation Run = 282
# Weights = [0.03  0.037 0.162 0.168 0.091 0.119 0.17  0.037 0.184], Final Value = $3994251.75, Sharpe Ratio = 1.11
#
#
# Simulation Run = 283
# Weights = [0.138 0.003 0.008 0.048 0.184 0.021 0.348 0.047 0.203], Final Value = $3064657.67, Sharpe Ratio = 0.88
#
#
# Simulation Run = 284
# Weights = [0.112 0.145 0.088 0.103 0.173 0.07  0.069 0.167 0.072], Final Value = $3544435.34, Sharpe Ratio = 1.03
#
#
# Simulation Run = 285
# Weights = [0.125 0.022 0.146 0.248 0.015 0.104 0.098 0.147 0.095], Final Value = $3907475.28, Sharpe Ratio = 1.12
#
#
# Simulation Run = 286
# Weights = [0.149 0.071 0.06  0.136 0.027 0.072 0.162 0.175 0.146], Final Value = $3422593.35, Sharpe Ratio = 0.98
#
#
# Simulation Run = 287
# Weights = [0.173 0.033 0.211 0.079 0.071 0.024 0.074 0.134 0.201], Final Value = $2972178.13, Sharpe Ratio = 0.93
#
#
# Simulation Run = 288
# Weights = [0.019 0.047 0.039 0.239 0.018 0.03  0.197 0.176 0.235], Final Value = $3114351.31, Sharpe Ratio = 0.89
#
#
# Simulation Run = 289
# Weights = [0.169 0.128 0.183 0.118 0.178 0.003 0.075 0.071 0.075], Final Value = $2830325.15, Sharpe Ratio = 0.88
#
#
# Simulation Run = 290
# Weights = [0.227 0.098 0.174 0.033 0.005 0.003 0.257 0.187 0.016], Final Value = $2822851.58, Sharpe Ratio = 0.86
#
#
# Simulation Run = 291
# Weights = [0.12  0.216 0.021 0.164 0.079 0.148 0.072 0.13  0.049], Final Value = $4016545.65, Sharpe Ratio = 0.99
#
#
# Simulation Run = 292
# Weights = [0.066 0.111 0.096 0.131 0.001 0.139 0.17  0.164 0.121], Final Value = $4072348.72, Sharpe Ratio = 1.10
#
#
# Simulation Run = 293
# Weights = [0.05  0.091 0.156 0.084 0.067 0.042 0.212 0.08  0.217], Final Value = $3102432.43, Sharpe Ratio = 0.92
#
#
# Simulation Run = 294
# Weights = [0.177 0.129 0.004 0.144 0.032 0.133 0.019 0.2   0.162], Final Value = $3820761.85, Sharpe Ratio = 0.95
#
#
# Simulation Run = 295
# Weights = [0.164 0.087 0.028 0.205 0.084 0.064 0.042 0.125 0.201], Final Value = $3230459.88, Sharpe Ratio = 0.87
#
#
# Simulation Run = 296
# Weights = [0.108 0.15  0.112 0.102 0.105 0.085 0.157 0.117 0.064], Final Value = $3591487.73, Sharpe Ratio = 1.03
#
#
# Simulation Run = 297
# Weights = [0.114 0.105 0.187 0.205 0.049 0.193 0.075 0.044 0.029], Final Value = $4624757.16, Sharpe Ratio = 1.17
#
#
# Simulation Run = 298
# Weights = [0.175 0.072 0.119 0.143 0.102 0.179 0.035 0.121 0.056], Final Value = $4538943.44, Sharpe Ratio = 1.17
#
#
# Simulation Run = 299
# Weights = [0.041 0.147 0.079 0.099 0.159 0.062 0.173 0.113 0.126], Final Value = $3421096.61, Sharpe Ratio = 0.99
#
#
# Simulation Run = 300
# Weights = [0.166 0.098 0.119 0.204 0.113 0.104 0.039 0.137 0.019], Final Value = $3889686.70, Sharpe Ratio = 1.08
#
#
# Simulation Run = 301
# Weights = [0.174 0.079 0.026 0.148 0.203 0.109 0.015 0.222 0.024], Final Value = $4096065.35, Sharpe Ratio = 1.11
#
#
# Simulation Run = 302
# Weights = [0.276 0.173 0.013 0.011 0.172 0.035 0.224 0.069 0.027], Final Value = $2937621.02, Sharpe Ratio = 0.77
#
#
# Simulation Run = 303
# Weights = [0.011 0.171 0.194 0.097 0.083 0.116 0.141 0.116 0.072], Final Value = $3934827.15, Sharpe Ratio = 1.11
#
#
# Simulation Run = 304
# Weights = [0.126 0.066 0.035 0.142 0.185 0.122 0.143 0.154 0.026], Final Value = $4223982.68, Sharpe Ratio = 1.17
#
#
# Simulation Run = 305
# Weights = [0.111 0.174 0.052 0.12  0.171 0.16  0.05  0.065 0.098], Final Value = $4191147.68, Sharpe Ratio = 1.04
#
#
# Simulation Run = 306
# Weights = [0.221 0.152 0.012 0.098 0.059 0.066 0.168 0.221 0.002], Final Value = $3381810.27, Sharpe Ratio = 0.92
#
#
# Simulation Run = 307
# Weights = [0.206 0.176 0.083 0.217 0.014 0.002 0.165 0.132 0.004], Final Value = $2663551.77, Sharpe Ratio = 0.76
#
#
# Simulation Run = 308
# Weights = [0.104 0.097 0.156 0.101 0.04  0.23  0.002 0.09  0.18 ], Final Value = $4792752.11, Sharpe Ratio = 1.15
#
#
# Simulation Run = 309
# Weights = [0.105 0.064 0.162 0.188 0.091 0.091 0.132 0.042 0.125], Final Value = $3677956.32, Sharpe Ratio = 1.06
#
#
# Simulation Run = 310
# Weights = [0.127 0.196 0.023 0.033 0.109 0.044 0.203 0.088 0.177], Final Value = $2897100.10, Sharpe Ratio = 0.77
#
#
# Simulation Run = 311
# Weights = [0.113 0.101 0.069 0.125 0.041 0.165 0.123 0.145 0.119], Final Value = $4288390.50, Sharpe Ratio = 1.12
#
#
# Simulation Run = 312
# Weights = [0.031 0.174 0.115 0.047 0.106 0.177 0.013 0.183 0.153], Final Value = $4405141.99, Sharpe Ratio = 1.12
#
#
# Simulation Run = 313
# Weights = [0.153 0.067 0.011 0.091 0.079 0.049 0.115 0.243 0.192], Final Value = $3235861.63, Sharpe Ratio = 0.93
#
#
# Simulation Run = 314
# Weights = [0.138 0.174 0.077 0.127 0.035 0.059 0.143 0.191 0.056], Final Value = $3257694.80, Sharpe Ratio = 0.93
#
#
# Simulation Run = 315
# Weights = [0.052 0.171 0.121 0.134 0.158 0.007 0.15  0.085 0.123], Final Value = $2843334.49, Sharpe Ratio = 0.86
#
#
# Simulation Run = 316
# Weights = [0.169 0.101 0.152 0.084 0.093 0.133 0.098 0.111 0.059], Final Value = $4049558.58, Sharpe Ratio = 1.12
#
#
# Simulation Run = 317
# Weights = [0.224 0.294 0.182 0.013 0.011 0.118 0.094 0.026 0.039], Final Value = $3341712.81, Sharpe Ratio = 0.76
#
#
# Simulation Run = 318
# Weights = [0.139 0.092 0.128 0.068 0.029 0.017 0.062 0.232 0.231], Final Value = $2811283.15, Sharpe Ratio = 0.84
#
#
# Simulation Run = 319
# Weights = [0.132 0.074 0.13  0.141 0.119 0.141 0.11  0.05  0.103], Final Value = $4134500.39, Sharpe Ratio = 1.12
#
#
# Simulation Run = 320
# Weights = [0.142 0.195 0.032 0.078 0.135 0.094 0.231 0.033 0.059], Final Value = $3499919.83, Sharpe Ratio = 0.91
#
#
# Simulation Run = 321
# Weights = [0.117 0.137 0.009 0.149 0.156 0.13  0.136 0.07  0.095], Final Value = $3976072.55, Sharpe Ratio = 1.03
#
#
# Simulation Run = 322
# Weights = [0.142 0.177 0.058 0.119 0.098 0.103 0.064 0.066 0.173], Final Value = $3441893.94, Sharpe Ratio = 0.88
#
#
# Simulation Run = 323
# Weights = [0.208 0.114 0.079 0.156 0.073 0.055 0.121 0.045 0.148], Final Value = $3045373.23, Sharpe Ratio = 0.83
#
#
# Simulation Run = 324
# Weights = [0.062 0.212 0.042 0.082 0.171 0.135 0.145 0.139 0.013], Final Value = $4122996.19, Sharpe Ratio = 1.08
#
#
# Simulation Run = 325
# Weights = [0.162 0.082 0.151 0.119 0.034 0.145 0.169 0.129 0.009], Final Value = $4242435.02, Sharpe Ratio = 1.16
#
#
# Simulation Run = 326
# Weights = [0.276 0.047 0.172 0.111 0.136 0.105 0.061 0.042 0.05 ], Final Value = $3769580.55, Sharpe Ratio = 1.00
#
#
# Simulation Run = 327
# Weights = [0.062 0.16  0.054 0.162 0.193 0.056 0.079 0.143 0.092], Final Value = $3420635.74, Sharpe Ratio = 0.98
#
#
# Simulation Run = 328
# Weights = [0.091 0.17  0.188 0.164 0.118 0.056 0.124 0.022 0.068], Final Value = $3251641.74, Sharpe Ratio = 0.94
#
#
# Simulation Run = 329
# Weights = [0.18  0.171 0.163 0.056 0.209 0.002 0.111 0.026 0.081], Final Value = $2700223.81, Sharpe Ratio = 0.80
#
#
# Simulation Run = 330
# Weights = [0.25  0.071 0.201 0.018 0.045 0.037 0.134 0.098 0.145], Final Value = $2944183.11, Sharpe Ratio = 0.85
#
#
# Simulation Run = 331
# Weights = [0.15  0.128 0.152 0.061 0.106 0.094 0.056 0.113 0.142], Final Value = $3546583.23, Sharpe Ratio = 1.00
#
#
# Simulation Run = 332
# Weights = [0.036 0.111 0.057 0.043 0.215 0.087 0.089 0.23  0.132], Final Value = $3855384.50, Sharpe Ratio = 1.11
#
#
# Simulation Run = 333
# Weights = [0.103 0.047 0.021 0.166 0.125 0.013 0.168 0.175 0.183], Final Value = $3021398.52, Sharpe Ratio = 0.93
#
#
# Simulation Run = 334
# Weights = [0.168 0.158 0.065 0.193 0.082 0.117 0.051 0.164 0.002], Final Value = $3891398.80, Sharpe Ratio = 1.02
#
#
# Simulation Run = 335
# Weights = [0.113 0.054 0.027 0.119 0.144 0.081 0.157 0.212 0.091], Final Value = $3796348.63, Sharpe Ratio = 1.12
#
#
# Simulation Run = 336
# Weights = [0.041 0.129 0.175 0.091 0.109 0.127 0.063 0.092 0.175], Final Value = $3929365.88, Sharpe Ratio = 1.08
#
#
# Simulation Run = 337
# Weights = [0.215 0.047 0.14  0.119 0.014 0.044 0.059 0.13  0.232], Final Value = $2963041.57, Sharpe Ratio = 0.84
#
#
# Simulation Run = 338
# Weights = [0.003 0.089 0.137 0.118 0.013 0.184 0.13  0.147 0.178], Final Value = $4529792.02, Sharpe Ratio = 1.18
#
#
# Simulation Run = 339
# Weights = [0.094 0.187 0.13  0.087 0.153 0.059 0.064 0.028 0.197], Final Value = $3081204.59, Sharpe Ratio = 0.84
#
#
# Simulation Run = 340
# Weights = [0.136 0.008 0.098 0.116 0.172 0.196 0.108 0.019 0.147], Final Value = $4731820.75, Sharpe Ratio = 1.19
#
#
# Simulation Run = 341
# Weights = [0.024 0.159 0.218 0.168 0.041 0.081 0.033 0.07  0.207], Final Value = $3349361.07, Sharpe Ratio = 0.91
#
#
# Simulation Run = 342
# Weights = [0.141 0.102 0.052 0.192 0.134 0.168 0.091 0.084 0.035], Final Value = $4454567.70, Sharpe Ratio = 1.13
#
#
# Simulation Run = 343
# Weights = [0.118 0.061 0.008 0.142 0.205 0.079 0.046 0.178 0.163], Final Value = $3681535.69, Sharpe Ratio = 1.04
#
#
# Simulation Run = 344
# Weights = [0.054 0.223 0.1   0.229 0.033 0.149 0.037 0.063 0.112], Final Value = $3923987.62, Sharpe Ratio = 0.94
#
#
# Simulation Run = 345
# Weights = [0.139 0.158 0.146 0.124 0.11  0.082 0.112 0.051 0.077], Final Value = $3442339.33, Sharpe Ratio = 0.97
#
#
# Simulation Run = 346
# Weights = [0.1   0.142 0.029 0.173 0.129 0.073 0.031 0.134 0.189], Final Value = $3351316.44, Sharpe Ratio = 0.90
#
#
# Simulation Run = 347
# Weights = [0.132 0.214 0.101 0.15  0.021 0.095 0.053 0.203 0.031], Final Value = $3558049.80, Sharpe Ratio = 0.95
#
#
# Simulation Run = 348
# Weights = [0.031 0.177 0.068 0.159 0.099 0.088 0.139 0.203 0.035], Final Value = $3760869.63, Sharpe Ratio = 1.06
#
#
# Simulation Run = 349
# Weights = [0.19  0.016 0.077 0.08  0.076 0.103 0.171 0.114 0.172], Final Value = $3724260.45, Sharpe Ratio = 1.03
#
#
# Simulation Run = 350
# Weights = [0.165 0.021 0.237 0.036 0.179 0.002 0.045 0.116 0.2  ], Final Value = $2899228.14, Sharpe Ratio = 0.94
#
#
# Simulation Run = 351
# ...
# Weights = [0.043 0.069 0.127 0.155 0.148 0.106 0.073 0.156 0.123], Final Value = $4016381.40, Sharpe Ratio = 1.17
#
#
# Simulation Run = 4885
# Weights = [0.029 0.073 0.15  0.119 0.176 0.175 0.162 0.042 0.074], Final Value = $4679718.11, Sharpe Ratio = 1.25
#
#
# Simulation Run = 4886
# Weights = [0.247 0.165 0.155 0.024 0.072 0.025 0.059 0.137 0.116], Final Value = $2738495.92, Sharpe Ratio = 0.76
#
#
# Simulation Run = 4887
# Weights = [0.004 0.109 0.149 0.315 0.138 0.079 0.026 0.124 0.056], Final Value = $3811749.25, Sharpe Ratio = 1.07
#
#
# Simulation Run = 4888
# Weights = [0.003 0.067 0.174 0.148 0.107 0.132 0.145 0.08  0.144], Final Value = $4192558.82, Sharpe Ratio = 1.17
#
#
# Simulation Run = 4889
# Weights = [0.168 0.012 0.061 0.172 0.162 0.004 0.173 0.05  0.196], Final Value = $2852457.74, Sharpe Ratio = 0.87
#
#
# Simulation Run = 4890
# Weights = [0.191 0.16  0.121 0.143 0.101 0.063 0.079 0.096 0.046], Final Value = $3273742.73, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4891
# Weights = [0.253 0.091 0.058 0.188 0.247 0.    0.11  0.019 0.033], Final Value = $2851219.74, Sharpe Ratio = 0.82
#
#
# Simulation Run = 4892
# Weights = [0.148 0.124 0.028 0.008 0.056 0.217 0.207 0.141 0.071], Final Value = $4747534.11, Sharpe Ratio = 1.15
#
#
# Simulation Run = 4893
# Weights = [0.101 0.196 0.028 0.239 0.001 0.143 0.16  0.101 0.032], Final Value = $3969865.05, Sharpe Ratio = 0.97
#
#
# Simulation Run = 4894
# Weights = [0.024 0.09  0.012 0.019 0.251 0.141 0.055 0.189 0.22 ], Final Value = $4278872.93, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4895
# Weights = [0.055 0.134 0.131 0.114 0.112 0.088 0.125 0.147 0.094], Final Value = $3701508.54, Sharpe Ratio = 1.08
#
#
# Simulation Run = 4896
# Weights = [0.119 0.054 0.012 0.06  0.15  0.191 0.198 0.109 0.107], Final Value = $4701051.06, Sharpe Ratio = 1.20
#
#
# Simulation Run = 4897
# Weights = [0.024 0.117 0.111 0.268 0.023 0.226 0.037 0.048 0.144], Final Value = $4825073.91, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4898
# Weights = [0.095 0.221 0.075 0.055 0.017 0.116 0.191 0.115 0.115], Final Value = $3576221.03, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4899
# Weights = [0.199 0.204 0.12  0.087 0.015 0.128 0.086 0.161 0.   ], Final Value = $3805392.06, Sharpe Ratio = 0.97
#
#
# Simulation Run = 4900
# Weights = [0.171 0.077 0.133 0.053 0.082 0.148 0.135 0.092 0.108], Final Value = $4131471.71, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4901
# Weights = [0.149 0.08  0.081 0.076 0.142 0.024 0.172 0.116 0.16 ], Final Value = $3006819.35, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4902
# Weights = [0.152 0.132 0.058 0.229 0.074 0.058 0.089 0.056 0.152], Final Value = $3110559.61, Sharpe Ratio = 0.84
#
#
# Simulation Run = 4903
# Weights = [0.033 0.174 0.142 0.053 0.177 0.091 0.038 0.135 0.157], Final Value = $3635917.93, Sharpe Ratio = 1.02
#
#
# Simulation Run = 4904
# Weights = [0.132 0.019 0.221 0.103 0.054 0.071 0.071 0.173 0.156], Final Value = $3571678.46, Sharpe Ratio = 1.10
#
#
# Simulation Run = 4905
# Weights = [0.178 0.144 0.099 0.142 0.074 0.066 0.129 0.018 0.151], Final Value = $3103158.54, Sharpe Ratio = 0.83
#
#
# Simulation Run = 4906
# Weights = [0.095 0.182 0.056 0.086 0.193 0.062 0.039 0.226 0.062], Final Value = $3487509.48, Sharpe Ratio = 1.00
#
#
# Simulation Run = 4907
# Weights = [0.055 0.165 0.148 0.224 0.084 0.02  0.19  0.092 0.021], Final Value = $3065300.80, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4908
# Weights = [0.097 0.083 0.133 0.115 0.177 0.073 0.068 0.089 0.165], Final Value = $3531416.74, Sharpe Ratio = 1.04
#
#
# Simulation Run = 4909
# Weights = [0.132 0.167 0.149 0.065 0.024 0.165 0.073 0.007 0.219], Final Value = $3875197.68, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4910
# Weights = [0.145 0.168 0.152 0.122 0.106 0.159 0.084 0.016 0.048], Final Value = $4143648.46, Sharpe Ratio = 1.05
#
#
# Simulation Run = 4911
# Weights = [0.028 0.219 0.121 0.024 0.146 0.131 0.15  0.136 0.045], Final Value = $4054713.17, Sharpe Ratio = 1.09
#
#
# Simulation Run = 4912
# Weights = [0.146 0.114 0.147 0.067 0.074 0.163 0.122 0.043 0.123], Final Value = $4163574.01, Sharpe Ratio = 1.08
#
#
# Simulation Run = 4913
# Weights = [0.102 0.09  0.086 0.101 0.134 0.108 0.094 0.156 0.128], Final Value = $3885193.45, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4914
# Weights = [0.147 0.192 0.089 0.146 0.159 0.101 0.006 0.067 0.094], Final Value = $3569865.83, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4915
# Weights = [0.09  0.047 0.139 0.146 0.123 0.127 0.132 0.124 0.072], Final Value = $4224825.90, Sharpe Ratio = 1.22
#
#
# Simulation Run = 4916
# Weights = [0.146 0.155 0.039 0.063 0.151 0.142 0.023 0.11  0.171], Final Value = $3923343.79, Sharpe Ratio = 0.98
#
#
# Simulation Run = 4917
# Weights = [0.163 0.099 0.162 0.123 0.084 0.121 0.012 0.128 0.107], Final Value = $3887962.35, Sharpe Ratio = 1.07
#
#
# Simulation Run = 4918
# Weights = [0.054 0.128 0.2   0.118 0.187 0.003 0.178 0.026 0.106], Final Value = $2907539.41, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4919
# Weights = [0.009 0.062 0.114 0.2   0.125 0.088 0.21  0.061 0.132], Final Value = $3802485.77, Sharpe Ratio = 1.08
#
#
# Simulation Run = 4920
# Weights = [0.179 0.13  0.074 0.033 0.171 0.183 0.098 0.074 0.058], Final Value = $4468970.22, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4921
# Weights = [0.094 0.113 0.167 0.093 0.132 0.233 0.086 0.008 0.074], Final Value = $4979609.69, Sharpe Ratio = 1.21
#
#
# Simulation Run = 4922
# Weights = [0.167 0.217 0.033 0.205 0.03  0.061 0.164 0.085 0.037], Final Value = $3093030.95, Sharpe Ratio = 0.80
#
#
# Simulation Run = 4923
# Weights = [0.147 0.088 0.176 0.074 0.124 0.086 0.115 0.052 0.139], Final Value = $3544338.20, Sharpe Ratio = 1.02
#
#
# Simulation Run = 4924
# Weights = [0.08  0.185 0.005 0.16  0.097 0.164 0.086 0.143 0.08 ], Final Value = $4255876.02, Sharpe Ratio = 1.05
#
#
# Simulation Run = 4925
# Weights = [0.152 0.082 0.038 0.183 0.153 0.066 0.113 0.054 0.158], Final Value = $3352999.11, Sharpe Ratio = 0.93
#
#
# Simulation Run = 4926
# Weights = [0.079 0.177 0.158 0.077 0.176 0.025 0.112 0.103 0.092], Final Value = $3039096.16, Sharpe Ratio = 0.93
#
#
# Simulation Run = 4927
# Weights = [0.02  0.153 0.066 0.094 0.13  0.159 0.156 0.147 0.075], Final Value = $4397355.41, Sharpe Ratio = 1.16
#
#
# Simulation Run = 4928
# Weights = [0.182 0.173 0.031 0.016 0.231 0.022 0.165 0.027 0.154], Final Value = $2773355.33, Sharpe Ratio = 0.76
#
#
# Simulation Run = 4929
# Weights = [0.237 0.207 0.079 0.033 0.054 0.004 0.173 0.155 0.057], Final Value = $2547059.14, Sharpe Ratio = 0.71
#
#
# Simulation Run = 4930
# Weights = [0.11  0.094 0.195 0.063 0.034 0.142 0.167 0.014 0.182], Final Value = $3915630.60, Sharpe Ratio = 1.04
#
#
# Simulation Run = 4931
# Weights = [0.035 0.211 0.007 0.175 0.191 0.141 0.042 0.013 0.183], Final Value = $3896274.46, Sharpe Ratio = 0.90
#
#
# Simulation Run = 4932
# Weights = [0.119 0.142 0.152 0.015 0.074 0.086 0.15  0.127 0.135], Final Value = $3477225.21, Sharpe Ratio = 1.00
#
#
# Simulation Run = 4933
# Weights = [0.178 0.098 0.051 0.094 0.145 0.183 0.125 0.013 0.114], Final Value = $4386583.17, Sharpe Ratio = 1.06
#
#
# Simulation Run = 4934
# Weights = [0.184 0.13  0.026 0.212 0.081 0.055 0.007 0.058 0.246], Final Value = $2913191.20, Sharpe Ratio = 0.73
#
#
# Simulation Run = 4935
# Weights = [0.075 0.196 0.073 0.112 0.095 0.241 0.092 0.003 0.112], Final Value = $4801539.48, Sharpe Ratio = 1.07
#
#
# Simulation Run = 4936
# Weights = [0.049 0.231 0.134 0.196 0.067 0.014 0.13  0.025 0.154], Final Value = $2620213.44, Sharpe Ratio = 0.71
#
#
# Simulation Run = 4937
# Weights = [0.103 0.075 0.141 0.19  0.097 0.04  0.02  0.124 0.21 ], Final Value = $3121866.83, Sharpe Ratio = 0.93
#
#
# Simulation Run = 4938
# Weights = [0.122 0.089 0.048 0.247 0.152 0.088 0.156 0.038 0.059], Final Value = $3718427.35, Sharpe Ratio = 1.02
#
#
# Simulation Run = 4939
# Weights = [0.175 0.17  0.089 0.08  0.149 0.081 0.12  0.015 0.122], Final Value = $3299068.25, Sharpe Ratio = 0.87
#
#
# Simulation Run = 4940
# Weights = [0.221 0.194 0.067 0.066 0.206 0.118 0.013 0.012 0.102], Final Value = $3611381.51, Sharpe Ratio = 0.86
#
#
# Simulation Run = 4941
# Weights = [0.025 0.13  0.234 0.019 0.025 0.201 0.203 0.155 0.007], Final Value = $4854007.24, Sharpe Ratio = 1.29
#
#
# Simulation Run = 4942
# Weights = [0.1   0.16  0.15  0.048 0.14  0.064 0.14  0.186 0.011], Final Value = $3550024.33, Sharpe Ratio = 1.07
#
#
# Simulation Run = 4943
# Weights = [0.191 0.09  0.113 0.068 0.059 0.17  0.072 0.218 0.018], Final Value = $4483521.27, Sharpe Ratio = 1.18
#
#
# Simulation Run = 4944
# Weights = [0.159 0.06  0.176 0.172 0.037 0.168 0.018 0.068 0.144], Final Value = $4261544.30, Sharpe Ratio = 1.10
#
#
# Simulation Run = 4945
# Weights = [0.238 0.075 0.02  0.265 0.148 0.057 0.07  0.059 0.067], Final Value = $3310003.72, Sharpe Ratio = 0.88
#
#
# Simulation Run = 4946
# Weights = [0.207 0.039 0.103 0.182 0.154 0.203 0.017 0.081 0.014], Final Value = $4871687.21, Sharpe Ratio = 1.18
#
#
# Simulation Run = 4947
# Weights = [0.087 0.044 0.096 0.112 0.205 0.145 0.142 0.05  0.118], Final Value = $4351829.10, Sharpe Ratio = 1.18
#
#
# Simulation Run = 4948
# Weights = [0.044 0.158 0.152 0.16  0.032 0.007 0.213 0.09  0.145], Final Value = $2739691.81, Sharpe Ratio = 0.82
#
#
# Simulation Run = 4949
# Weights = [0.204 0.097 0.027 0.025 0.196 0.205 0.23  0.012 0.003], Final Value = $4759982.26, Sharpe Ratio = 1.12
#
#
# Simulation Run = 4950
# Weights = [0.125 0.009 0.114 0.1   0.132 0.097 0.146 0.122 0.156], Final Value = $3855083.58, Sharpe Ratio = 1.14
#
#
# Simulation Run = 4951
# Weights = [0.159 0.016 0.17  0.092 0.186 0.148 0.157 0.043 0.029], Final Value = $4459233.18, Sharpe Ratio = 1.23
#
#
# Simulation Run = 4952
# Weights = [0.14  0.008 0.108 0.143 0.244 0.084 0.023 0.011 0.239], Final Value = $3626155.33, Sharpe Ratio = 0.99
#
#
# Simulation Run = 4953
# Weights = [0.119 0.105 0.123 0.161 0.113 0.046 0.156 0.038 0.138], Final Value = $3149365.84, Sharpe Ratio = 0.92
#
#
# Simulation Run = 4954
# Weights = [0.033 0.102 0.117 0.146 0.131 0.088 0.133 0.103 0.147], Final Value = $3701694.58, Sharpe Ratio = 1.07
#
#
# Simulation Run = 4955
# Weights = [0.098 0.082 0.141 0.148 0.026 0.163 0.112 0.17  0.06 ], Final Value = $4437640.16, Sharpe Ratio = 1.21
#
#
# Simulation Run = 4956
# Weights = [0.019 0.204 0.174 0.163 0.038 0.059 0.076 0.096 0.171], Final Value = $3126931.27, Sharpe Ratio = 0.86
#
#
# Simulation Run = 4957
# Weights = [0.231 0.078 0.092 0.045 0.131 0.208 0.167 0.029 0.019], Final Value = $4728858.53, Sharpe Ratio = 1.13
#
#
# Simulation Run = 4958
# Weights = [0.146 0.068 0.056 0.34  0.011 0.176 0.082 0.077 0.045], Final Value = $4458849.11, Sharpe Ratio = 1.07
#
#
# Simulation Run = 4959
# Weights = [0.236 0.092 0.219 0.011 0.164 0.113 0.089 0.071 0.004], Final Value = $3928245.21, Sharpe Ratio = 1.07
#
#
# Simulation Run = 4960
# Weights = [0.154 0.019 0.11  0.145 0.16  0.051 0.142 0.06  0.16 ], Final Value = $3352320.21, Sharpe Ratio = 1.00
#
#
# Simulation Run = 4961
# Weights = [0.14  0.169 0.04  0.16  0.17  0.043 0.072 0.046 0.159], Final Value = $2981336.48, Sharpe Ratio = 0.81
#
#
# Simulation Run = 4962
# Weights = [0.239 0.048 0.15  0.052 0.091 0.017 0.154 0.093 0.157], Final Value = $2832881.13, Sharpe Ratio = 0.85
#
#
# Simulation Run = 4963
# Weights = [0.059 0.197 0.011 0.015 0.026 0.224 0.249 0.152 0.066], Final Value = $4770882.99, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4964
# Weights = [0.215 0.084 0.053 0.092 0.129 0.158 0.095 0.083 0.091], Final Value = $4207257.32, Sharpe Ratio = 1.06
#
#
# Simulation Run = 4965
# Weights = [0.067 0.108 0.037 0.129 0.011 0.153 0.172 0.19  0.133], Final Value = $4206631.80, Sharpe Ratio = 1.10
#
#
# Simulation Run = 4966
# Weights = [0.12  0.174 0.085 0.062 0.049 0.145 0.12  0.108 0.137], Final Value = $3905683.10, Sharpe Ratio = 1.00
#
#
# Simulation Run = 4967
# Weights = [0.123 0.106 0.139 0.038 0.164 0.142 0.206 0.066 0.015], Final Value = $4274659.61, Sharpe Ratio = 1.18
#
#
# Simulation Run = 4968
# Weights = [0.159 0.013 0.054 0.033 0.067 0.243 0.172 0.195 0.064], Final Value = $5264278.33, Sharpe Ratio = 1.30
#
#
# Simulation Run = 4969
# Weights = [0.083 0.058 0.027 0.101 0.073 0.103 0.226 0.204 0.125], Final Value = $3909061.30, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4970
# Weights = [0.1   0.191 0.069 0.001 0.133 0.113 0.196 0.054 0.143], Final Value = $3622785.60, Sharpe Ratio = 0.94
#
#
# Simulation Run = 4971
# Weights = [0.111 0.082 0.159 0.077 0.127 0.104 0.138 0.065 0.137], Final Value = $3779649.37, Sharpe Ratio = 1.09
#
#
# Simulation Run = 4972
# Weights = [0.031 0.134 0.037 0.15  0.154 0.119 0.156 0.143 0.076], Final Value = $4069030.66, Sharpe Ratio = 1.11
#
#
# Simulation Run = 4973
# Weights = [0.119 0.04  0.215 0.182 0.035 0.029 0.141 0.154 0.083], Final Value = $3238275.18, Sharpe Ratio = 1.04
#
#
# Simulation Run = 4974
# Weights = [0.016 0.206 0.045 0.038 0.221 0.258 0.011 0.175 0.031], Final Value = $5371231.02, Sharpe Ratio = 1.22
#
#
# Simulation Run = 4975
# Weights = [0.032 0.043 0.156 0.229 0.205 0.026 0.197 0.068 0.043], Final Value = $3463751.33, Sharpe Ratio = 1.08
#
#
# Simulation Run = 4976
# Weights = [0.121 0.214 0.007 0.069 0.078 0.065 0.058 0.215 0.174], Final Value = $3121665.15, Sharpe Ratio = 0.81
#
#
# Simulation Run = 4977
# Weights = [0.213 0.118 0.045 0.119 0.08  0.018 0.165 0.2   0.041], Final Value = $2970491.97, Sharpe Ratio = 0.88
#
#
# Simulation Run = 4978
# Weights = [0.136 0.023 0.061 0.    0.221 0.2   0.105 0.204 0.05 ], Final Value = $5056237.22, Sharpe Ratio = 1.32
#
#
# Simulation Run = 4979
# Weights = [0.103 0.155 0.122 0.173 0.062 0.022 0.08  0.089 0.195], Final Value = $2751511.62, Sharpe Ratio = 0.79
#
#
# Simulation Run = 4980
# Weights = [0.145 0.036 0.228 0.023 0.184 0.205 0.069 0.012 0.1  ], Final Value = $4832420.91, Sharpe Ratio = 1.24
#
#
# Simulation Run = 4981
# Weights = [0.118 0.007 0.009 0.256 0.118 0.087 0.108 0.08  0.218], Final Value = $3634630.26, Sharpe Ratio = 0.98
#
#
# Simulation Run = 4982
# Weights = [0.115 0.164 0.156 0.013 0.043 0.164 0.105 0.166 0.074], Final Value = $4239602.85, Sharpe Ratio = 1.13
#
#
# Simulation Run = 4983
# Weights = [0.017 0.191 0.14  0.035 0.068 0.135 0.05  0.143 0.221], Final Value = $3837444.26, Sharpe Ratio = 0.99
#
#
# Simulation Run = 4984
# Weights = [0.107 0.121 0.011 0.052 0.183 0.122 0.179 0.088 0.137], Final Value = $3922786.08, Sharpe Ratio = 1.04
#
#
# Simulation Run = 4985
# Weights = [0.133 0.141 0.128 0.13  0.027 0.009 0.1   0.17  0.163], Final Value = $2698179.74, Sharpe Ratio = 0.81
#
#
# Simulation Run = 4986
# Weights = [0.138 0.085 0.125 0.082 0.268 0.036 0.076 0.063 0.125], Final Value = $3255613.09, Sharpe Ratio = 0.98
#
#
# Simulation Run = 4987
# Weights = [0.082 0.023 0.23  0.036 0.134 0.118 0.098 0.054 0.226], Final Value = $3943137.10, Sharpe Ratio = 1.13
#
#
# Simulation Run = 4988
# Weights = [0.041 0.074 0.039 0.192 0.074 0.213 0.029 0.193 0.145], Final Value = $4907920.18, Sharpe Ratio = 1.21
#
#
# Simulation Run = 4989
# Weights = [0.129 0.03  0.056 0.146 0.145 0.13  0.128 0.093 0.145], Final Value = $4116659.65, Sharpe Ratio = 1.12
#
#
# Simulation Run = 4990
# Weights = [0.256 0.061 0.062 0.067 0.051 0.31  0.091 0.058 0.045], Final Value = $5578602.29, Sharpe Ratio = 1.16
#
#
# Simulation Run = 4991
# Weights = [0.058 0.235 0.056 0.107 0.227 0.107 0.108 0.05  0.051], Final Value = $3762509.54, Sharpe Ratio = 0.97
#
#
# Simulation Run = 4992
# Weights = [0.195 0.131 0.139 0.008 0.107 0.112 0.124 0.125 0.061], Final Value = $3778249.59, Sharpe Ratio = 1.04
#
#
# Simulation Run = 4993
# Weights = [0.154 0.214 0.04  0.051 0.247 0.033 0.13  0.028 0.102], Final Value = $2917494.37, Sharpe Ratio = 0.79
#
#
# Simulation Run = 4994
# Weights = [0.134 0.207 0.1   0.154 0.094 0.198 0.035 0.002 0.077], Final Value = $4366011.17, Sharpe Ratio = 1.00
#
#
# Simulation Run = 4995
# Weights = [0.153 0.14  0.134 0.092 0.138 0.038 0.041 0.17  0.094], Final Value = $3153537.28, Sharpe Ratio = 0.95
#
#
# Simulation Run = 4996
# Weights = [0.066 0.1   0.113 0.179 0.056 0.176 0.157 0.057 0.097], Final Value = $4446252.05, Sharpe Ratio = 1.15
#
#
# Simulation Run = 4997
# Weights = [0.096 0.152 0.094 0.161 0.113 0.109 0.028 0.121 0.126], Final Value = $3740052.90, Sharpe Ratio = 1.01
#
#
# Simulation Run = 4998
# Weights = [0.024 0.156 0.141 0.043 0.09  0.239 0.015 0.266 0.027], Final Value = $5254558.06, Sharpe Ratio = 1.30
#
#
# Simulation Run = 4999
# Weights = [0.003 0.078 0.051 0.2   0.2   0.189 0.037 0.165 0.076], Final Value = $4930068.33, Sharpe Ratio = 1.25

# %%
sharpe_ratio_runs
# Out:
# array([1.13630547, 1.09457429, 0.82763611, ..., 1.01056444, 1.30172324,
#        1.24575159], shape=(5000,))

# %%
sharpe_ratio_runs.argmax()
# Out:
# np.int64(3215)

# %%
sharpe_ratio_runs.max()
# Out:
# np.float64(1.4732083336672548)

# %%
weights_runs[sharpe_ratio_runs.argmax(), :]
# Out:
# array([0.03149201, 0.00312216, 0.27240665, 0.00670591, 0.12598324,
#        0.25541027, 0.07887367, 0.18342851, 0.04257758])

# %%
# Return Sharpe ratio, volatility corresponding to the best weights allocation (maximum Sharpe ratio)
optimal_portfolio_return, optimal_volatility, optimal_sharpe_ratio, highest_final_value, optimal_return_on_investment = simulation_engine(weights_runs[sharpe_ratio_runs.argmax(), :], initial_investment)
print('Best Portfolio Metrics Based on {} Monte Carlo Simulation Runs:'.format(sim_runs))
print('  - Portfolio Expected Annual Return = {:.02f}%'.format(optimal_portfolio_return * 100))
print('  - Portfolio Standard Deviation (Volatility) = {:.02f}%'.format(optimal_volatility * 100))
print('  - Sharpe Ratio = {:.02f}'.format(optimal_sharpe_ratio))
print('  - Final Value = INR {:.02f}'.format(highest_final_value))
print('  - Return on Investment = {:.02f}%'.format(optimal_return_on_investment))
# Out:
# Best Portfolio Metrics Based on 5000 Monte Carlo Simulation Runs:
#   - Portfolio Expected Annual Return = 30.70%
#   - Portfolio Standard Deviation (Volatility) = 16.09%
#   - Sharpe Ratio = 1.47
#   - Final Value = INR 5673219.08
#   - Return on Investment = 467.32%

# %%
sim_out_df = pd.DataFrame({'Volatility': volatility_runs.tolist(), 'Portfolio_Return': expected_portfolio_returns_runs.tolist(), 'Sharpe_Ratio': sharpe_ratio_runs.tolist() })
sim_out_df
# Out:
#       Volatility  Portfolio_Return  Sharpe_Ratio
# 0       0.153242          0.244130      1.136305
# 1       0.148552          0.232601      1.094574
# 2       0.151564          0.195440      0.827636
# 3       0.147334          0.212066      0.964246
# 4       0.158236          0.254573      1.166439
# ...          ...               ...           ...
# 4995    0.146693          0.209018      0.947675
# 4996    0.158047          0.251310      1.147189
# 4997    0.151301          0.222900      1.010564
# 4998    0.158667          0.276541      1.301723
# 4999    0.165534          0.276214      1.245752
#
# [5000 rows x 3 columns]

# %%
# Plot volatility vs. return for all simulation runs
# Highlight the volatility and return that corresponds to the highest Sharpe ratio
import plotly.graph_objects as go
fig = px.scatter(sim_out_df, x = 'Volatility', y = 'Portfolio_Return', color = 'Sharpe_Ratio', size = 'Sharpe_Ratio', hover_data = ['Sharpe_Ratio'] )
fig.update_layout({'plot_bgcolor': "white"})
fig.show()

# %%
# Let's highlight the point with the highest Sharpe ratio
fig = px.scatter(sim_out_df, x = 'Volatility', y = 'Portfolio_Return', color = 'Sharpe_Ratio', size = 'Sharpe_Ratio', hover_data = ['Sharpe_Ratio'] )
fig.add_trace(go.Scatter(x = [optimal_volatility], y = [optimal_portfolio_return], mode = 'markers', name = 'Optimal Point', marker = dict(size=[40], color = 'red')))
fig.update_layout(coloraxis_colorbar = dict(y = 0.7, dtick = 5))
fig.update_layout({'plot_bgcolor': "white"})
fig.show()
